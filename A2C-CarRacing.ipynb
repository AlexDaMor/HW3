# %% [markdown]
# Синхронный A2C.
# Используется объект "менеджер" (manager) который создает несколько объектов "рабочих" (workers), код которых работает последовательно в одном потоке.
# - Каждый рабочий имеет собственный environment и экземпляр сети, менеджер владеет целевой сетью.
# - Каждый рабочий имеет собственный счетчик эпизодов и функцию, которая генерирует траекторию.
# - Функция возвращает результаты по траекториям пока не будет завершено заданное при создании рабочего количество эпизодов. Счетчик стейтов, - через переменные объекта рабочего.
# - После завершения n-step траектории или эпизода рабочий возвращает менеджеру все необходимые данные для расчета loss-а.
# - Менеджер последовательно вызывает функции рабочих и обрабатывает возвращаемые траектории, пока хоть один из рабочих что-то возвращает.
# - Получив траекторию от рабочего, менеджер рассчитывает loss, копирует в целевую сеть накопленные градиенты рабочего, выполняет backward pass и обновляет веса собственной (целевой) сети. Затем градиенты обнуляются, веса целевой сети копируются в сеть текущего рабочего.
# - На каждом цикле перебора менеджер пропускает случайного рабочего, чтобы не было синхронизации, так как длина эпизодов обычно одинаковая - максимальная.
# - сеть (рабочего) оценивается на каждом лучшем эпизоде, сохраняется видео и чекпойнт. Лучшим считается эпизод с нагадой которая более чем на 50 боллов выше предыдущего глобального лучшего.

# %% [markdown]
# Класс для модели

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions
from torch.utils.tensorboard import SummaryWriter

import numpy as np
import gymnasium as gym

from collections import deque
import cv2

import os

from gymnasium.wrappers.monitoring.video_recorder import VideoRecorder
from IPython.display import HTML
from base64 import b64encode
from pyvirtualdisplay import Display

# %% [markdown]
# Класс модели

# %%
class CarRacing_CNN_Model(nn.Module):   
            
    def __init__(self, fstack_size):
        super(CarRacing_CNN_Model, self).__init__()        
        
        self.gru_hidden_state = None 
        # Общий feature extractor
        # В сеть передаются обесцвеченные (grayscale) кадры размером 84x84. 
        # Количество кадров в последовательности - fstack_size 
        # Кадры последовательности интерпретируются как каналы на входе cnn
        self.cnn = nn.Sequential(
            nn.BatchNorm2d(fstack_size),
            nn.Conv2d(4, 32, 4, stride=2, padding=1),
            nn.LeakyReLU(0.2), 
            nn.Conv2d(32, 32, 3, stride=2, padding=1),
            nn.LeakyReLU(0.2), 
            nn.Conv2d(32, 32, 3, stride=2, padding=1),
            nn.LeakyReLU(0.2), 
            nn.Conv2d(32, 32, 3, stride=2, padding=1),
            nn.LeakyReLU(0.2), 
            nn.BatchNorm2d(32),
            nn.Flatten()          
        )
        
        cnn_out_size = int(np.prod(self.cnn(torch.zeros(1, fstack_size, 84, 84)).size()))
               
        #Инициализация FE
        self.cnn.apply(self.init_cnn_weights)        
        
        self.gru = nn.GRU(cnn_out_size, 256, 1, batch_first=True) # Вместо LSTM из оригинальной статьи  
        
        
        #голова Actor (mean - [-1 : 1])
        self.mu = nn.Sequential(
            nn.Linear(256, 3),
            nn.Tanh()
        )
        #голова Actor (std dev - [0 : 1])        
        self.sigma = nn.Sequential(
            nn.Linear(256, 3),
            nn.Softplus() 
        )  
        
        # голова Critic
        self.value = nn.Linear(256, 1)
        
        
        
            
                                  
    #-------------------------------------------------------------------------------------------------------------------------
    
    def init_cnn_weights(self, m):            
            if type(m) == nn.Conv2d:
                nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('leaky_relu'))
                nn.init.constant_(m.bias, 0.01)    
                            
    #-------------------------------------------------------------------------------------------------------------------------
    
    def reset_gru(self):
        if self.gru_hidden_state != None:
            self.gru_hidden_state = None
                            
    #-------------------------------------------------------------------------------------------------------------------------
             
    def forward(self, state):
        cnn_out=self.cnn(state) 

        if self.gru_hidden_state == None:
            gru_out, hs = self.gru(cnn_out)
        else:    
            gru_out, hs = self.gru(cnn_out, self.gru_hidden_state) 

        self.gru_hidden_state = hs.detach()
         
        mu = self.mu(gru_out)
        sigma = self.sigma(gru_out)
        value = self.value(gru_out)
        return mu, sigma, value

# %% [markdown]
# Класс рабочего

# %%
class Worker:
    def __init__(self, id, target, num_episodes, fstack_size, device):
        
        self.device = device
        self.model = CarRacing_CNN_Model(fstack_size).to(self.device)
        self.model.load_state_dict(target.state_dict())
        self.episodes_left_to_do = num_episodes        
        self.__is_alive = True
        self.episode_steps = []
        self.episode_reward = 0
        self.episode_rewards = []
        self.best_ep_reward = -10000        

        self.id = id
        self.framestack = deque(maxlen=fstack_size)
        self.steps_done = 0
        self.last_steps_rewards = deque(maxlen=100)
        
        self.env = gym.make("CarRacing-v2", render_mode="rgb_array", lap_complete_percent=0.95, domain_randomize=False)   
        print(f'Worker {self.id} is ready')
        self.new_episode()  
    
    #-------------------------------------------------------------------------------------------------------------------------
         
    def revive(self):  
        if self.episodes_left_to_do > 0 and not self.__is_alive:
            self.__is_alive = True
            return 1
        else:
            return 0
    
    #-------------------------------------------------------------------------------------------------------------------------
        
    def kill(self):  
        if self.__is_alive:
            self.__is_alive = False        
            return -1
        else:
            return 0
    
    #-------------------------------------------------------------------------------------------------------------------------
    
    def is_alive(self):
        return self.__is_alive
    
    #-------------------------------------------------------------------------------------------------------------------------
    
    def preprocess_state(self, image):
        image=image[:84, 6:90] #обрезаем лишнее        
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)  # удаляем цвет        
        image = image / 255.0 # нормализуем
        return image  
        
    #-------------------------------------------------------------------------------------------------------------------------
    
    def preprocess(self, states):

        return torch.stack([torch.from_numpy(self.preprocess_state(image_data)) for image_data in states]).float()
                           
    #----------------------------------------------------------------------------------------------------------------------
        
    def predict (self, model, states, greedy = False):
        
        t_framestack= self.preprocess(states).to(self.device)        
        t_framestack = t_framestack.unsqueeze(0) # (+)batch_dim, 
        
        # Получаем предсказание от сети , 
        mu_t, sigma_t, value_t = model(t_framestack)        
        mu_t = mu_t.squeeze() #(-)batch_dim        
        sigma_t = sigma_t.squeeze() #(-)batch_dim        
                
        action_dist = distributions.normal.Normal(mu_t, sigma_t)
        if greedy:
            action = mu_t
            log_prob_t = None
            entropy = None
            value_t = None
        else:
            action = action_dist.sample()
            log_prob_t = action_dist.log_prob(action)
            entropy=action_dist.entropy()
            value_t=value_t.squeeze(0)
        
        # Подрезаем значения действий
        action_t = torch.clamp(action, torch.tensor([-1.0, 0.0, 0.0]).to(self.device), torch.tensor([1.0, 1.0, 1.0]).to(self.device))
        return log_prob_t, entropy, action_t, value_t
    
    #----------------------------------------------------------------------------------------------------------------------
         
    def new_episode(self):
        self.env.reset()
        self.framestack.clear()
        self.model.reset_gru()
        self.episode_reward = 0
        # Пропускаем наезд камеры в начале эпизода
        action_none = np.array([0,0,0])
        for _ in range(50):            
            state, _, _, _, _ = self.env.step(np.array(action_none))
            self.framestack.append(state) 

                          
        
    #----------------------------------------------------------------------------------------------------------------------
        
    def get_n_step_data(self, trajectory_len, gamma):
        
        step=0
        log_probs_t = torch.zeros (0,3).to(self.device)
        entropies_t = torch.zeros (0,3).to(self.device)
        values_t = torch.zeros (0).to(self.device)
        self.rewards = []
        terminal = None
        return_ep_reward = None
        if self.is_alive:
            while True: 
                self.steps_done +=1            
                step +=1
                log_prob_t, entropy, action_t, value_t = self.predict(self.model, self.framestack)
            
                state, reward, terminated, truncated, _ = self.env.step(action_t.cpu().numpy())
                terminal = terminated or truncated
                log_probs_t = torch.cat((log_probs_t, log_prob_t.unsqueeze(0)))
                entropies_t = torch.cat((entropies_t, entropy.unsqueeze(0)))
                values_t = torch.cat((values_t, value_t))  
                self.rewards.append(reward)  
                self.episode_reward += reward
                self.last_steps_rewards.append(reward)                
                last_val = value_t.detach().item()         
                self.framestack.append(state)
                

                if terminal or (step % trajectory_len == 0): #Закончилась траектория или эпизод
                    # Считаем дисконтированные награды
                    returns = []                 
                    if terminal:
                        R = 0
                    else:                    
                        R = last_val                                                   
                    for r in self.rewards[::-1]:
                        R = r + gamma*R 
                        returns.append(R)
                    returns.reverse()                
                    if terminal:
                        # В случае конца эпизода проверяем дополнительные условия
                        if self.episodes_left_to_do > 0: # Если не конец всех эпизодов
                            self.episode_rewards.append(self.episode_reward) 
                            return_ep_reward = self.episode_reward
                            self.new_episode() 
                            self.episodes_left_to_do -= 1                                                                              
                        else:                        
                            # Если конец всех эпизодов, ставим заглушку на эту функцию, 
                            # чтобы она при повторных вызовах возвращала только None
                            # Менеджер и не вызовет ее повторно, перед вызовом проверяет флаг.                    
                            self.__is_alive = False 
                            return_ep_reward = None  
                                             
                    break                                                
        return return_ep_reward, returns, log_probs_t, values_t, entropies_t, step
         
    #----------------------------------------------------------------------------------------------------------------------
    
    def log_stats(self, writer):
        if len(self.episode_rewards)>0:
            writer.add_scalar('worker/'+str(self.id)+'/Ep.reward', self.episode_rewards[-1], self.steps_done)
        writer.add_scalar('worker/'+str(self.id)+'/last 100 reward mean', np.mean(self.last_steps_rewards), self.steps_done)

# %% [markdown]
# Класс менеджера

# %%
class Manager:
    def __init__(self,                 
                 gamma = 0.99,
                 tau = 0.5, # Коэф. для Polyak update 
                 lr = 0.00001,
                 ent_coef = 0.0001, #масштабирование enropy loss
                 clip_grad_norm = 40, #ограничение градиента
                 value_coef = 0.5, #масштабирование value loss
                 steps_per_update = 100, #Длина траектории. Если поставить дробь на которую нет целочисленных делений (0.3)                 
                 checkpoint_reward_threshold = 300, #Сохранять лучшую модель при награде больше чем...
                 num_workers = 1-6, # количество рабочих сетей
                 num_episodes = 10000, # это количества поделится на всех рабочих
                 worker_start_offset = 100,
                 start_model_path = None, #загрузить модель и начать с нее  
                 fstack_size = 8               
                 ):
        
        
        self.gamma = gamma
        self.tau = tau
        self.ent_coef = ent_coef
        self.clip_grad_norm = clip_grad_norm
        self.value_coef = value_coef
        self.steps_per_update = steps_per_update
        self.checkpoint_reward_threshold = checkpoint_reward_threshold
        self.num_workers = num_workers
        self.num_episodes = num_episodes
        self.worker_start_offset = worker_start_offset
        self.start_model_path = start_model_path
        self.max_eval_reward = -10000
        self.fstack_size = fstack_size
        
        self.loss_p_log = deque(maxlen=100)
        self.loss_v_log = deque(maxlen=100)
        self.loss_e_log = deque(maxlen=100)
        self.loss_log = deque(maxlen=100)
        
        self.best_eval_reward = -1000
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.target_net = CarRacing_CNN_Model(self.fstack_size).to(self.device)
        #self.target_net.share_memory()
        self.optimizer = optim.Adam(self.target_net.parameters(), lr=lr, weight_decay=0.000005) #, weight_decay=0.00001
        self.scheduler = torch.optim.lr_scheduler.StepLR(
                    self.optimizer, step_size=100, gamma=0.9)
        self.tf_writer = SummaryWriter(flush_secs = 10, comment="_CarRacingA2C")
        
        
        os.environ['PYVIRTUALDISPLAY_DISPLAYFD'] = '0'
        # create the directory to store the video(s)
        os.makedirs("./video", exist_ok=True)
        display = Display(visible=False, size=(800, 600))
        _ = display.start()

        #Создаем рабочих
        self.workers = [Worker(id, self.target_net, num_episodes=self.num_episodes//self.num_workers, fstack_size = self.fstack_size, device=self.device) for id in range(self.num_workers)]
        
    #---------------------------------------------------------------------------------------------------------------------------------    
    
    def train_model(self):
        episodes_done = 0
        steps_done = 0               
        live_workers = 8         
        skip_this_worker = 7        
        traininng_complete = False        
        best_ep_reward = -1000  
        if self.start_model_path is not None:
            self.target_net.load_state_dict(torch.load(self.start_model_path, map_location=self.device))
            print (f'Model loaded from {self.start_model_path}')        
        while live_workers > 0:            
            # На каждом проходе цикла пропускаем одного рабочего, если все живы
            if live_workers == self.num_workers:
                skip_this_worker = np.random.randint(0, live_workers) 
                live_workers += self.workers[skip_this_worker].kill()
            else:    
                live_workers += self.workers[skip_this_worker].revive()
            for worker in self.workers:                
                if worker.is_alive():  
                      
                    ep_reward, returns, log_probs, values, entropies, steps = worker.get_n_step_data(self.steps_per_update, self.gamma)
                    if ep_reward is not None:
                        terminal = True
                        self.tf_writer.add_scalar('Reward/Episode reward', ep_reward, steps_done)
                    else:
                        terminal = False
                    steps_done += steps
                    
                    self.update_target_weights(worker, returns, log_probs, values, entropies)
                    self.tf_writer.add_scalar('Loss/Loss', np.mean(self.loss_log), steps_done)
                    self.tf_writer.add_scalar('Loss/Policy', np.mean(self.loss_p_log), steps_done)
                    self.tf_writer.add_scalar('Loss/Value', np.mean(self.loss_v_log), steps_done)
                    self.tf_writer.add_scalar('Loss/Entropy', np.mean(self.loss_e_log), steps_done)                    
                    self.tf_writer.flush()
                    
                    if terminal:
                        episodes_done += 1                        
                        print(f'Worker {worker.id} finished episode {episodes_done}. Reward {ep_reward:.0f}. LR={self.scheduler.get_last_lr()}')
                        
                        # При завершении эпизода проверяем, нужно ли сохранять модель
                        if ep_reward > best_ep_reward:
                            for worker in self.workers:
                                worker.best_ep_reward = ep_reward
                        if ep_reward > best_ep_reward+50 and ep_reward > self.checkpoint_reward_threshold:
                            print(f'New best episode reward {ep_reward:.0f}. Evaluating worker network, saving video and checkpoint')
                            best_ep_reward = ep_reward
                            target_reward = self.greedy_run(worker.model, episodes_done, render = True)                                                                                                               
                            self.tf_writer.add_scalar('Target/Trigger', ep_reward, steps_done)
                            self.tf_writer.add_scalar('Target/Evaluation Reward', target_reward, steps_done)
                            torch.save(worker.model.state_dict(), f'./models/model_ep_{episodes_done}_rew_{ep_reward:.0f}.pth')
                            print (f'Model saved to ./models/model_ep_{episodes_done}_rew_{ep_reward:.0f}.pth')                             
                        if ep_reward > 950: #Проверка на завершение обучения
                            worker_rewards=[]
                            print ('Ep reward > 950, evaluating worker network for 10 eps')
                            for _ in range(10):
                                worker_rewards.append(self.greedy_run(worker.model, episodes_done, render=False))
                            print (f'Target network evaluation done. Mean 10 eps reward {np.mean(worker_rewards):.0f}')
                            if np.mean(worker_rewards) > 800:
                                print (f'Since mean 10 eps reward >800 ({np.mean(worker_rewards):.0f}), will do a full 100 eps evaluation')
                                worker_rewards=[]
                                for _ in range(100):
                                    worker_rewards.append(self.greedy_run(worker.model, episodes_done, render=False))
                                if np.mean(worker_rewards) > 900:
                                    print (f'Mean 100 eps reward >900 ({np.mean(worker_rewards):.0f}), training finished')  
                                    traininng_complete = True
                                    print (f'Saving final model ./models/Final_model_ep_{episodes_done}_rew_{ep_reward:.0f}.pth') 
                                    torch.save(worker.model.state_dict(), f'./models/Final_model_ep_{episodes_done}_rew_{ep_reward:.0f}.pth')
                                self.greedy_run(worker.model, episodes_done, render=True)
            if traininng_complete:
                break
        print (f'Training done.')
        
        
    #--------------------------------------------------------------------------------------------------------------------------------- 
      
    def update_target_weights(self, worker, returns, log_probs_t, values_t, entropies_t):
        
        # считаем лоссы 
        returns_t = torch.tensor(returns, dtype=torch.float32).to(self.device)
        advantage_t = returns_t - values_t

        value_loss = F.mse_loss(returns_t, values_t)*self.value_coef       
        policy_loss = -1*(advantage_t.unsqueeze(-1) * log_probs_t).mean() # 
        entropy_loss = self.ent_coef * entropies_t.mean()    
        
        loss = policy_loss + value_loss + entropy_loss  

        self.loss_v_log.append(value_loss.detach().cpu())
        self.loss_p_log.append(policy_loss.detach().cpu())
        self.loss_e_log.append(entropy_loss.detach().cpu())
        self.loss_log.append(loss.detach().cpu())

        loss.backward()
        # torch.nn.utils.clip_grad_norm_(worker.model.parameters(), self.clip_grad_norm)
        # сейчас просчитались градиенты рабочего. Теперь их надо загрузить в целевую сеть и обновить веса целевой сети (сделать шаг оптимизатора)
        for worker_param, target_param in zip(worker.model.named_parameters(),self.target_net.named_parameters()):
            target_param[1].grad = worker_param[1].grad    
        
        self.optimizer.step()

        
        # обнуляем градиенты везде куда дотянемся
        self.optimizer.zero_grad()
        self.target_net.zero_grad() 
        self.target_net.reset_gru() #Следующая последовательнось от другого рабочего    
        #загружаем веса из таргета в рабочую модель
        
        
     
        worker.model.load_state_dict(self.target_net.state_dict())
        
        worker.model.zero_grad()  
        

        return
    
    def render_mp4(self, videopath: str) -> str:
        mp4 = open(videopath, 'rb').read()
        base64_encoded_mp4 = b64encode(mp4).decode()
        return f'<video width=400 controls><source src="data:video/mp4;' \
                f'base64,{base64_encoded_mp4}" type="video/mp4"></video>'
                
    def greedy_run(self, model, episodes_done, render = False):
        eval_model = CarRacing_CNN_Model(self.fstack_size).to(self.device)          
        eval_model.load_state_dict(model.state_dict())
        env = gym.make("CarRacing-v2", render_mode="rgb_array", lap_complete_percent=0.95, domain_randomize=False) 
        if render:
            src_path = f"video/EVAL_{env.spec.id}_ep_{episodes_done}.mp4" 
        episode_reward = 0
        steps=0
        env.reset()                 
        tiles_open = 0    
        off_track=0         
        framestack = deque(maxlen=self.fstack_size)                              
        if render:
            vid = VideoRecorder(env, path=src_path) 
                     
        # Пропускаем наезд камеры в начале эпизода и заполняем буфер перед началом цикла:
        for _ in range(50):
            if render:
                env.render()
                vid.capture_frame()
            action_none = np.array([0,0,0])
            state, _, _, _, _ = env.step(action_none)
            framestack.append(state) 
            steps +=1    
                 
        # Основной цикл эпизода - отдаем выше данные каждые n-steps а также по концу эпизода:
        while True:
            if render:
                env.render()
                vid.capture_frame()
            _, _, action_t, _ = self.workers[0].predict(eval_model, framestack, greedy=True)            
            state, reward, terminated, truncated, _ = env.step(action_t.cpu().detach().numpy())            
            episode_reward += reward
            framestack.append(state)
            steps +=1   
            if reward > 0:
                tiles_open += 1
            if reward == -100:
                off_track += 1
            if terminated or truncated:
                break
        if render:
            vid.close()
            os.rename(src_path, f"video/EVAL_{env.spec.id}_ep_{episodes_done}_rew_{episode_reward:3.1f}.mp4")
        print (f'Target run, ep. {episodes_done}. Steps: {steps}  Reward: {episode_reward:3.1f}. Tiles opened: {np.mean(tiles_open):3.1f}. Gone out: {off_track:3.1f}')
        return episode_reward

# %% [markdown]
# Запуск всего этого добра

# %%
manager = Manager (
    gamma = 0.99, 
    lr = 0.00001,
    ent_coef = 0.0001,
    clip_grad_norm = 40,
    value_coef = 0.5,
    steps_per_update = 16, 
    checkpoint_reward_threshold = 100,
    num_workers = 8,
    num_episodes = 100000, # Поделятся на всех рабочих
    start_model_path = None, # 'models/model_ep_3247_rew_882).pth'
    tau = 0.99,
    fstack_size = 4
)

manager.train_model()
# Out:
# Worker 0 is ready
# Worker 1 is ready
# Worker 2 is ready
# Worker 3 is ready
# Worker 4 is ready
# Worker 5 is ready
# Worker 6 is ready
# Worker 7 is ready
# Worker 0 finished episode 1. Reward -76. LR=[1e-05]
# Worker 1 finished episode 2. Reward -72. LR=[1e-05]
# Worker 2 finished episode 3. Reward -69. LR=[1e-05]
# Worker 3 finished episode 4. Reward -72. LR=[1e-05]
# Worker 7 finished episode 5. Reward -77. LR=[1e-05]
# Worker 5 finished episode 6. Reward -73. LR=[1e-05]
# Worker 6 finished episode 7. Reward -67. LR=[1e-05]
# Worker 4 finished episode 8. Reward -71. LR=[1e-05]
# Worker 3 finished episode 9. Reward -76. LR=[1e-05]
# Worker 0 finished episode 10. Reward -82. LR=[1e-05]
# Worker 1 finished episode 11. Reward -77. LR=[1e-05]
# Worker 5 finished episode 12. Reward -78. LR=[1e-05]
# Worker 6 finished episode 13. Reward -78. LR=[1e-05]
# Worker 2 finished episode 14. Reward -85. LR=[1e-05]
# Worker 7 finished episode 15. Reward -81. LR=[1e-05]
# Worker 4 finished episode 16. Reward -82. LR=[1e-05]
# Worker 0 finished episode 17. Reward -81. LR=[1e-05]
# Worker 1 finished episode 18. Reward -85. LR=[1e-05]
# Worker 5 finished episode 19. Reward -82. LR=[1e-05]
# Worker 2 finished episode 20. Reward -73. LR=[1e-05]
# Worker 3 finished episode 21. Reward -81. LR=[1e-05]
# Worker 7 finished episode 22. Reward -80. LR=[1e-05]
# Worker 6 finished episode 23. Reward -81. LR=[1e-05]
# Worker 4 finished episode 24. Reward -77. LR=[1e-05]
# Worker 0 finished episode 25. Reward -82. LR=[1e-05]
# Worker 1 finished episode 26. Reward -85. LR=[1e-05]
# Worker 5 finished episode 27. Reward -82. LR=[1e-05]
# Worker 7 finished episode 28. Reward -82. LR=[1e-05]
# Worker 2 finished episode 29. Reward -84. LR=[1e-05]
# Worker 3 finished episode 30. Reward -83. LR=[1e-05]
# Worker 6 finished episode 31. Reward -81. LR=[1e-05]
# Worker 4 finished episode 32. Reward -84. LR=[1e-05]
# Worker 1 finished episode 33. Reward -78. LR=[1e-05]
# Worker 2 finished episode 34. Reward -77. LR=[1e-05]
# Worker 0 finished episode 35. Reward -84. LR=[1e-05]
# Worker 5 finished episode 36. Reward -81. LR=[1e-05]
# Worker 6 finished episode 37. Reward -80. LR=[1e-05]
# Worker 3 finished episode 38. Reward -81. LR=[1e-05]
# Worker 7 finished episode 39. Reward -81. LR=[1e-05]
# Worker 4 finished episode 40. Reward -80. LR=[1e-05]
# Worker 0 finished episode 41. Reward -81. LR=[1e-05]
# Worker 2 finished episode 42. Reward -83. LR=[1e-05]
# Worker 1 finished episode 43. Reward -81. LR=[1e-05]
# Worker 7 finished episode 44. Reward -81. LR=[1e-05]
# Worker 6 finished episode 45. Reward -85. LR=[1e-05]
# Worker 3 finished episode 46. Reward -84. LR=[1e-05]
# Worker 5 finished episode 47. Reward -84. LR=[1e-05]
# Worker 4 finished episode 48. Reward -82. LR=[1e-05]
# Worker 0 finished episode 49. Reward -84. LR=[1e-05]
# Worker 1 finished episode 50. Reward -80. LR=[1e-05]
# Worker 2 finished episode 51. Reward -77. LR=[1e-05]
# Worker 6 finished episode 52. Reward -81. LR=[1e-05]
# Worker 7 finished episode 53. Reward -83. LR=[1e-05]
# Worker 3 finished episode 54. Reward -77. LR=[1e-05]
# Worker 5 finished episode 55. Reward -77. LR=[1e-05]
# Worker 4 finished episode 56. Reward -81. LR=[1e-05]
# Worker 1 finished episode 57. Reward -79. LR=[1e-05]
# Worker 0 finished episode 58. Reward -82. LR=[1e-05]
# Worker 2 finished episode 59. Reward -81. LR=[1e-05]
# Worker 3 finished episode 60. Reward -78. LR=[1e-05]
# Worker 6 finished episode 61. Reward -79. LR=[1e-05]
# Worker 7 finished episode 62. Reward -85. LR=[1e-05]
# Worker 4 finished episode 63. Reward -77. LR=[1e-05]
# Worker 5 finished episode 64. Reward -81. LR=[1e-05]
# Worker 1 finished episode 65. Reward -85. LR=[1e-05]
# Worker 0 finished episode 66. Reward -75. LR=[1e-05]
# Worker 3 finished episode 67. Reward -78. LR=[1e-05]
# Worker 6 finished episode 68. Reward -76. LR=[1e-05]
# Worker 2 finished episode 69. Reward -77. LR=[1e-05]
# Worker 7 finished episode 70. Reward -77. LR=[1e-05]
# Worker 4 finished episode 71. Reward -71. LR=[1e-05]
# Worker 5 finished episode 72. Reward -76. LR=[1e-05]
# Worker 0 finished episode 73. Reward -81. LR=[1e-05]
# Worker 1 finished episode 74. Reward -85. LR=[1e-05]
# Worker 3 finished episode 75. Reward -78. LR=[1e-05]
# Worker 6 finished episode 76. Reward -83. LR=[1e-05]
# Worker 2 finished episode 77. Reward -80. LR=[1e-05]
# Worker 4 finished episode 78. Reward -82. LR=[1e-05]
# Worker 7 finished episode 79. Reward -82. LR=[1e-05]
# Worker 5 finished episode 80. Reward -86. LR=[1e-05]
# Worker 0 finished episode 81. Reward -83. LR=[1e-05]
# Worker 3 finished episode 82. Reward -84. LR=[1e-05]
# Worker 6 finished episode 83. Reward -81. LR=[1e-05]
# Worker 1 finished episode 84. Reward -82. LR=[1e-05]
# Worker 2 finished episode 85. Reward -84. LR=[1e-05]
# Worker 4 finished episode 86. Reward -82. LR=[1e-05]
# Worker 7 finished episode 87. Reward -85. LR=[1e-05]
# Worker 5 finished episode 88. Reward -82. LR=[1e-05]
# Worker 0 finished episode 89. Reward -79. LR=[1e-05]
# Worker 1 finished episode 90. Reward -82. LR=[1e-05]
# Worker 3 finished episode 91. Reward -85. LR=[1e-05]
# Worker 6 finished episode 92. Reward -80. LR=[1e-05]
# Worker 2 finished episode 93. Reward -85. LR=[1e-05]
# Worker 4 finished episode 94. Reward -82. LR=[1e-05]
# Worker 7 finished episode 95. Reward -82. LR=[1e-05]
# Worker 5 finished episode 96. Reward -84. LR=[1e-05]
# Worker 0 finished episode 97. Reward -80. LR=[1e-05]
# Worker 3 finished episode 98. Reward -80. LR=[1e-05]
# Worker 1 finished episode 99. Reward -75. LR=[1e-05]
# Worker 2 finished episode 100. Reward -83. LR=[1e-05]
# Worker 4 finished episode 101. Reward -85. LR=[1e-05]
# Worker 6 finished episode 102. Reward -83. LR=[1e-05]
# Worker 7 finished episode 103. Reward -85. LR=[1e-05]
# Worker 5 finished episode 104. Reward -82. LR=[1e-05]
# Worker 0 finished episode 105. Reward -82. LR=[1e-05]
# Worker 1 finished episode 106. Reward -73. LR=[1e-05]
# Worker 2 finished episode 107. Reward -78. LR=[1e-05]
# Worker 3 finished episode 108. Reward -73. LR=[1e-05]
# Worker 6 finished episode 109. Reward -75. LR=[1e-05]
# Worker 4 finished episode 110. Reward -82. LR=[1e-05]
# Worker 7 finished episode 111. Reward -84. LR=[1e-05]
# Worker 5 finished episode 112. Reward -82. LR=[1e-05]
# Worker 0 finished episode 113. Reward -85. LR=[1e-05]
# Worker 1 finished episode 114. Reward -79. LR=[1e-05]
# Worker 3 finished episode 115. Reward -73. LR=[1e-05]
# Worker 6 finished episode 116. Reward -71. LR=[1e-05]
# Worker 2 finished episode 117. Reward -71. LR=[1e-05]
# Worker 7 finished episode 118. Reward -66. LR=[1e-05]
# Worker 4 finished episode 119. Reward -78. LR=[1e-05]
# Worker 5 finished episode 120. Reward -65. LR=[1e-05]
# Worker 0 finished episode 121. Reward -68. LR=[1e-05]
# Worker 1 finished episode 122. Reward -75. LR=[1e-05]
# Worker 7 finished episode 123. Reward -68. LR=[1e-05]
# Worker 2 finished episode 124. Reward -77. LR=[1e-05]
# Worker 6 finished episode 125. Reward -82. LR=[1e-05]
# Worker 3 finished episode 126. Reward -87. LR=[1e-05]
# Worker 4 finished episode 127. Reward -79. LR=[1e-05]
# Worker 5 finished episode 128. Reward -84. LR=[1e-05]
# Worker 0 finished episode 129. Reward -73. LR=[1e-05]
# Worker 1 finished episode 130. Reward -75. LR=[1e-05]
# Worker 2 finished episode 131. Reward -85. LR=[1e-05]
# Worker 3 finished episode 132. Reward -73. LR=[1e-05]
# Worker 6 finished episode 133. Reward -84. LR=[1e-05]
# Worker 7 finished episode 134. Reward -61. LR=[1e-05]
# Worker 4 finished episode 135. Reward -74. LR=[1e-05]
# Worker 5 finished episode 136. Reward -75. LR=[1e-05]
# Worker 0 finished episode 137. Reward -63. LR=[1e-05]
# Worker 1 finished episode 138. Reward -36. LR=[1e-05]
# Worker 2 finished episode 139. Reward -81. LR=[1e-05]
# Worker 3 finished episode 140. Reward -82. LR=[1e-05]
# Worker 6 finished episode 141. Reward -69. LR=[1e-05]
# Worker 7 finished episode 142. Reward -68. LR=[1e-05]
# Worker 4 finished episode 143. Reward -61. LR=[1e-05]
# Worker 5 finished episode 144. Reward -58. LR=[1e-05]
# Worker 0 finished episode 145. Reward -76. LR=[1e-05]
# Worker 1 finished episode 146. Reward -71. LR=[1e-05]
# Worker 3 finished episode 147. Reward -63. LR=[1e-05]
# Worker 2 finished episode 148. Reward -77. LR=[1e-05]
# Worker 7 finished episode 149. Reward -82. LR=[1e-05]
# Worker 6 finished episode 150. Reward -62. LR=[1e-05]
# Worker 4 finished episode 151. Reward -83. LR=[1e-05]
# Worker 5 finished episode 152. Reward -67. LR=[1e-05]
# Worker 1 finished episode 153. Reward -63. LR=[1e-05]
# Worker 7 finished episode 154. Reward -81. LR=[1e-05]
# Worker 2 finished episode 155. Reward -59. LR=[1e-05]
# Worker 3 finished episode 156. Reward -58. LR=[1e-05]
# Worker 0 finished episode 157. Reward -67. LR=[1e-05]
# Worker 6 finished episode 158. Reward -52. LR=[1e-05]
# Worker 4 finished episode 159. Reward -73. LR=[1e-05]
# Worker 5 finished episode 160. Reward -14. LR=[1e-05]
# Worker 3 finished episode 161. Reward -53. LR=[1e-05]
# Worker 7 finished episode 162. Reward -69. LR=[1e-05]
# Worker 1 finished episode 163. Reward -70. LR=[1e-05]
# Worker 2 finished episode 164. Reward -77. LR=[1e-05]
# Worker 0 finished episode 165. Reward -78. LR=[1e-05]
# Worker 6 finished episode 166. Reward -68. LR=[1e-05]
# Worker 4 finished episode 167. Reward -81. LR=[1e-05]
# Worker 5 finished episode 168. Reward -58. LR=[1e-05]
# Worker 2 finished episode 169. Reward -24. LR=[1e-05]
# Worker 1 finished episode 170. Reward -56. LR=[1e-05]
# Worker 7 finished episode 171. Reward -73. LR=[1e-05]
# Worker 3 finished episode 172. Reward -60. LR=[1e-05]
# Worker 0 finished episode 173. Reward -83. LR=[1e-05]
# Worker 6 finished episode 174. Reward -75. LR=[1e-05]
# Worker 4 finished episode 175. Reward -51. LR=[1e-05]
# Worker 5 finished episode 176. Reward -76. LR=[1e-05]
# Worker 1 finished episode 177. Reward -71. LR=[1e-05]
# Worker 2 finished episode 178. Reward -50. LR=[1e-05]
# Worker 3 finished episode 179. Reward -43. LR=[1e-05]
# Worker 7 finished episode 180. Reward -82. LR=[1e-05]
# Worker 0 finished episode 181. Reward -29. LR=[1e-05]
# Worker 6 finished episode 182. Reward -72. LR=[1e-05]
# Worker 4 finished episode 183. Reward -17. LR=[1e-05]
# Worker 5 finished episode 184. Reward -61. LR=[1e-05]
# Worker 1 finished episode 185. Reward -52. LR=[1e-05]
# Worker 2 finished episode 186. Reward -68. LR=[1e-05]
# Worker 3 finished episode 187. Reward -52. LR=[1e-05]
# Worker 0 finished episode 188. Reward -70. LR=[1e-05]
# Worker 6 finished episode 189. Reward -49. LR=[1e-05]
# Worker 7 finished episode 190. Reward -60. LR=[1e-05]
# Worker 4 finished episode 191. Reward -68. LR=[1e-05]
# Worker 5 finished episode 192. Reward -58. LR=[1e-05]
# Worker 1 finished episode 193. Reward -55. LR=[1e-05]
# Worker 2 finished episode 194. Reward -35. LR=[1e-05]
# Worker 3 finished episode 195. Reward -67. LR=[1e-05]
# Worker 0 finished episode 196. Reward -51. LR=[1e-05]
# Worker 4 finished episode 197. Reward -62. LR=[1e-05]
# Worker 6 finished episode 198. Reward -23. LR=[1e-05]
# Worker 7 finished episode 199. Reward -55. LR=[1e-05]
# Worker 5 finished episode 200. Reward -67. LR=[1e-05]
# Worker 1 finished episode 201. Reward -49. LR=[1e-05]
# Worker 3 finished episode 202. Reward -44. LR=[1e-05]
# Worker 2 finished episode 203. Reward -55. LR=[1e-05]
# Worker 6 finished episode 204. Reward -75. LR=[1e-05]
# Worker 0 finished episode 205. Reward -54. LR=[1e-05]
# Worker 4 finished episode 206. Reward -61. LR=[1e-05]
# Worker 7 finished episode 207. Reward -66. LR=[1e-05]
# Worker 5 finished episode 208. Reward -60. LR=[1e-05]
# Worker 1 finished episode 209. Reward -44. LR=[1e-05]
# Worker 3 finished episode 210. Reward -73. LR=[1e-05]
# Worker 2 finished episode 211. Reward -60. LR=[1e-05]
# Worker 0 finished episode 212. Reward -46. LR=[1e-05]
# Worker 6 finished episode 213. Reward -54. LR=[1e-05]
# Worker 4 finished episode 214. Reward -41. LR=[1e-05]
# Worker 7 finished episode 215. Reward -73. LR=[1e-05]
# Worker 5 finished episode 216. Reward -64. LR=[1e-05]
# Worker 1 finished episode 217. Reward -39. LR=[1e-05]
# Worker 3 finished episode 218. Reward -44. LR=[1e-05]
# Worker 2 finished episode 219. Reward -64. LR=[1e-05]
# Worker 0 finished episode 220. Reward -69. LR=[1e-05]
# Worker 6 finished episode 221. Reward -56. LR=[1e-05]
# Worker 7 finished episode 222. Reward -35. LR=[1e-05]
# Worker 4 finished episode 223. Reward -62. LR=[1e-05]
# Worker 5 finished episode 224. Reward -69. LR=[1e-05]
# Worker 1 finished episode 225. Reward -39. LR=[1e-05]
# Worker 3 finished episode 226. Reward -32. LR=[1e-05]
# Worker 2 finished episode 227. Reward -54. LR=[1e-05]
# Worker 0 finished episode 228. Reward -65. LR=[1e-05]
# Worker 6 finished episode 229. Reward -46. LR=[1e-05]
# Worker 7 finished episode 230. Reward -66. LR=[1e-05]
# Worker 4 finished episode 231. Reward -5. LR=[1e-05]
# Worker 5 finished episode 232. Reward -16. LR=[1e-05]
# Worker 3 finished episode 233. Reward -65. LR=[1e-05]
# Worker 1 finished episode 234. Reward -61. LR=[1e-05]
# Worker 2 finished episode 235. Reward -72. LR=[1e-05]
# Worker 6 finished episode 236. Reward -58. LR=[1e-05]
# Worker 0 finished episode 237. Reward -68. LR=[1e-05]
# Worker 7 finished episode 238. Reward -49. LR=[1e-05]
# Worker 4 finished episode 239. Reward -58. LR=[1e-05]
# Worker 5 finished episode 240. Reward -56. LR=[1e-05]
# Worker 1 finished episode 241. Reward -54. LR=[1e-05]
# Worker 3 finished episode 242. Reward -36. LR=[1e-05]
# Worker 2 finished episode 243. Reward -35. LR=[1e-05]
# Worker 6 finished episode 244. Reward -37. LR=[1e-05]
# Worker 0 finished episode 245. Reward -73. LR=[1e-05]
# Worker 4 finished episode 246. Reward -58. LR=[1e-05]
# Worker 7 finished episode 247. Reward -55. LR=[1e-05]
# Worker 5 finished episode 248. Reward -25. LR=[1e-05]
# Worker 3 finished episode 249. Reward -61. LR=[1e-05]
# Worker 1 finished episode 250. Reward -41. LR=[1e-05]
# Worker 2 finished episode 251. Reward -69. LR=[1e-05]
# Worker 6 finished episode 252. Reward -16. LR=[1e-05]
# Worker 0 finished episode 253. Reward -60. LR=[1e-05]
# Worker 4 finished episode 254. Reward -36. LR=[1e-05]
# Worker 7 finished episode 255. Reward -71. LR=[1e-05]
# Worker 5 finished episode 256. Reward -39. LR=[1e-05]
# Worker 3 finished episode 257. Reward -45. LR=[1e-05]
# Worker 1 finished episode 258. Reward -53. LR=[1e-05]
# Worker 2 finished episode 259. Reward -58. LR=[1e-05]
# Worker 6 finished episode 260. Reward -56. LR=[1e-05]
# Worker 7 finished episode 261. Reward -37. LR=[1e-05]
# Worker 4 finished episode 262. Reward -60. LR=[1e-05]
# Worker 0 finished episode 263. Reward -57. LR=[1e-05]
# Worker 5 finished episode 264. Reward -63. LR=[1e-05]
# Worker 3 finished episode 265. Reward -78. LR=[1e-05]
# Worker 2 finished episode 266. Reward -60. LR=[1e-05]
# Worker 1 finished episode 267. Reward -82. LR=[1e-05]
# Worker 6 finished episode 268. Reward -69. LR=[1e-05]
# Worker 7 finished episode 269. Reward -11. LR=[1e-05]
# Worker 4 finished episode 270. Reward -25. LR=[1e-05]
# Worker 0 finished episode 271. Reward -42. LR=[1e-05]
# Worker 5 finished episode 272. Reward -35. LR=[1e-05]
# Worker 3 finished episode 273. Reward -36. LR=[1e-05]
# Worker 2 finished episode 274. Reward -24. LR=[1e-05]
# Worker 1 finished episode 275. Reward -67. LR=[1e-05]
# Worker 6 finished episode 276. Reward -60. LR=[1e-05]
# Worker 7 finished episode 277. Reward -69. LR=[1e-05]
# Worker 4 finished episode 278. Reward -77. LR=[1e-05]
# Worker 0 finished episode 279. Reward -39. LR=[1e-05]
# Worker 5 finished episode 280. Reward -20. LR=[1e-05]
# Worker 3 finished episode 281. Reward -19. LR=[1e-05]
# Worker 1 finished episode 282. Reward -76. LR=[1e-05]
# Worker 2 finished episode 283. Reward -75. LR=[1e-05]
# Worker 6 finished episode 284. Reward -41. LR=[1e-05]
# Worker 7 finished episode 285. Reward -32. LR=[1e-05]
# Worker 0 finished episode 286. Reward -65. LR=[1e-05]
# Worker 4 finished episode 287. Reward -30. LR=[1e-05]
# Worker 5 finished episode 288. Reward -79. LR=[1e-05]
# Worker 3 finished episode 289. Reward -45. LR=[1e-05]
# Worker 1 finished episode 290. Reward -22. LR=[1e-05]
# Worker 2 finished episode 291. Reward -61. LR=[1e-05]
# Worker 6 finished episode 292. Reward -41. LR=[1e-05]
# Worker 7 finished episode 293. Reward -72. LR=[1e-05]
# Worker 0 finished episode 294. Reward -38. LR=[1e-05]
# Worker 4 finished episode 295. Reward -26. LR=[1e-05]
# Worker 5 finished episode 296. Reward -60. LR=[1e-05]
# Worker 1 finished episode 297. Reward -51. LR=[1e-05]
# Worker 3 finished episode 298. Reward -29. LR=[1e-05]
# Worker 2 finished episode 299. Reward -63. LR=[1e-05]
# Worker 6 finished episode 300. Reward -24. LR=[1e-05]
# Worker 7 finished episode 301. Reward 80. LR=[1e-05]
# Worker 0 finished episode 302. Reward 27. LR=[1e-05]
# Worker 4 finished episode 303. Reward 2. LR=[1e-05]
# Worker 5 finished episode 304. Reward -79. LR=[1e-05]
# Worker 1 finished episode 305. Reward -77. LR=[1e-05]
# Worker 3 finished episode 306. Reward -75. LR=[1e-05]
# Worker 2 finished episode 307. Reward -15. LR=[1e-05]
# Worker 6 finished episode 308. Reward -58. LR=[1e-05]
# Worker 7 finished episode 309. Reward -8. LR=[1e-05]
# Worker 0 finished episode 310. Reward -61. LR=[1e-05]
# Worker 4 finished episode 311. Reward -70. LR=[1e-05]
# Worker 5 finished episode 312. Reward -67. LR=[1e-05]
# Worker 2 finished episode 313. Reward -56. LR=[1e-05]
# Worker 3 finished episode 314. Reward -66. LR=[1e-05]
# Worker 1 finished episode 315. Reward -72. LR=[1e-05]
# Worker 6 finished episode 316. Reward -14. LR=[1e-05]
# Worker 7 finished episode 317. Reward -15. LR=[1e-05]
# Worker 0 finished episode 318. Reward -69. LR=[1e-05]
# Worker 4 finished episode 319. Reward -25. LR=[1e-05]
# Worker 5 finished episode 320. Reward -33. LR=[1e-05]
# Worker 2 finished episode 321. Reward -24. LR=[1e-05]
# Worker 3 finished episode 322. Reward -29. LR=[1e-05]
# Worker 1 finished episode 323. Reward -41. LR=[1e-05]
# Worker 6 finished episode 324. Reward -76. LR=[1e-05]
# Worker 7 finished episode 325. Reward -77. LR=[1e-05]
# Worker 0 finished episode 326. Reward -45. LR=[1e-05]
# Worker 4 finished episode 327. Reward -50. LR=[1e-05]
# Worker 5 finished episode 328. Reward -40. LR=[1e-05]
# Worker 2 finished episode 329. Reward -31. LR=[1e-05]
# Worker 1 finished episode 330. Reward -36. LR=[1e-05]
# Worker 3 finished episode 331. Reward -58. LR=[1e-05]
# Worker 6 finished episode 332. Reward -32. LR=[1e-05]
# Worker 7 finished episode 333. Reward -33. LR=[1e-05]
# Worker 0 finished episode 334. Reward -31. LR=[1e-05]
# Worker 4 finished episode 335. Reward -45. LR=[1e-05]
# Worker 5 finished episode 336. Reward -30. LR=[1e-05]
# Worker 2 finished episode 337. Reward -33. LR=[1e-05]
# Worker 3 finished episode 338. Reward -68. LR=[1e-05]
# Worker 1 finished episode 339. Reward 20. LR=[1e-05]
# Worker 6 finished episode 340. Reward -60. LR=[1e-05]
# Worker 7 finished episode 341. Reward -60. LR=[1e-05]
# Worker 0 finished episode 342. Reward -50. LR=[1e-05]
# Worker 4 finished episode 343. Reward -5. LR=[1e-05]
# Worker 5 finished episode 344. Reward -66. LR=[1e-05]
# Worker 2 finished episode 345. Reward -55. LR=[1e-05]
# Worker 1 finished episode 346. Reward -44. LR=[1e-05]
# Worker 3 finished episode 347. Reward -41. LR=[1e-05]
# Worker 6 finished episode 348. Reward -45. LR=[1e-05]
# Worker 7 finished episode 349. Reward -79. LR=[1e-05]
# Worker 0 finished episode 350. Reward -46. LR=[1e-05]
# Worker 4 finished episode 351. Reward -33. LR=[1e-05]
# Worker 5 finished episode 352. Reward -49. LR=[1e-05]
# Worker 2 finished episode 353. Reward -69. LR=[1e-05]
# Worker 3 finished episode 354. Reward -47. LR=[1e-05]
# Worker 1 finished episode 355. Reward -56. LR=[1e-05]
# Worker 6 finished episode 356. Reward -22. LR=[1e-05]
# Worker 0 finished episode 357. Reward -51. LR=[1e-05]
# Worker 7 finished episode 358. Reward -33. LR=[1e-05]
# Worker 4 finished episode 359. Reward -63. LR=[1e-05]
# Worker 5 finished episode 360. Reward -34. LR=[1e-05]
# Worker 2 finished episode 361. Reward -44. LR=[1e-05]
# Worker 3 finished episode 362. Reward -50. LR=[1e-05]
# Worker 1 finished episode 363. Reward -38. LR=[1e-05]
# Worker 6 finished episode 364. Reward -64. LR=[1e-05]
# Worker 0 finished episode 365. Reward -17. LR=[1e-05]
# Worker 7 finished episode 366. Reward -13. LR=[1e-05]
# Worker 4 finished episode 367. Reward -42. LR=[1e-05]
# Worker 5 finished episode 368. Reward -52. LR=[1e-05]
# Worker 2 finished episode 369. Reward -40. LR=[1e-05]
# Worker 3 finished episode 370. Reward -46. LR=[1e-05]
# Worker 1 finished episode 371. Reward -20. LR=[1e-05]
# Worker 6 finished episode 372. Reward -62. LR=[1e-05]
# Worker 0 finished episode 373. Reward -75. LR=[1e-05]
# Worker 7 finished episode 374. Reward -51. LR=[1e-05]
# Worker 5 finished episode 375. Reward -70. LR=[1e-05]
# Worker 4 finished episode 376. Reward -15. LR=[1e-05]
# Worker 2 finished episode 377. Reward -35. LR=[1e-05]
# Worker 0 finished episode 378. Reward -58. LR=[1e-05]
# Worker 1 finished episode 379. Reward -59. LR=[1e-05]
# Worker 3 finished episode 380. Reward -58. LR=[1e-05]
# Worker 6 finished episode 381. Reward -62. LR=[1e-05]
# Worker 7 finished episode 382. Reward -43. LR=[1e-05]
# Worker 5 finished episode 383. Reward -56. LR=[1e-05]
# Worker 4 finished episode 384. Reward -27. LR=[1e-05]
# Worker 2 finished episode 385. Reward -18. LR=[1e-05]
# Worker 0 finished episode 386. Reward -36. LR=[1e-05]
# Worker 3 finished episode 387. Reward -48. LR=[1e-05]
# Worker 1 finished episode 388. Reward -50. LR=[1e-05]
# Worker 6 finished episode 389. Reward -30. LR=[1e-05]
# Worker 7 finished episode 390. Reward -33. LR=[1e-05]
# Worker 5 finished episode 391. Reward -46. LR=[1e-05]
# Worker 4 finished episode 392. Reward -28. LR=[1e-05]
# Worker 2 finished episode 393. Reward 5. LR=[1e-05]
# Worker 0 finished episode 394. Reward -62. LR=[1e-05]
# Worker 3 finished episode 395. Reward -26. LR=[1e-05]
# Worker 1 finished episode 396. Reward -26. LR=[1e-05]
# Worker 6 finished episode 397. Reward -25. LR=[1e-05]
# Worker 7 finished episode 398. Reward -31. LR=[1e-05]
# Worker 5 finished episode 399. Reward -29. LR=[1e-05]
# Worker 4 finished episode 400. Reward -25. LR=[1e-05]
# Worker 2 finished episode 401. Reward -35. LR=[1e-05]
# Worker 0 finished episode 402. Reward 4. LR=[1e-05]
# Worker 3 finished episode 403. Reward 2. LR=[1e-05]
# Worker 1 finished episode 404. Reward -56. LR=[1e-05]
# Worker 6 finished episode 405. Reward -55. LR=[1e-05]
# Worker 7 finished episode 406. Reward -15. LR=[1e-05]
# Worker 5 finished episode 407. Reward -54. LR=[1e-05]
# Worker 4 finished episode 408. Reward -39. LR=[1e-05]
# Worker 2 finished episode 409. Reward 21. LR=[1e-05]
# Worker 0 finished episode 410. Reward -57. LR=[1e-05]
# Worker 3 finished episode 411. Reward -28. LR=[1e-05]
# Worker 1 finished episode 412. Reward 111. LR=[1e-05]
# New best episode reward 111. Evaluating worker network, saving video and checkpoint
# Moviepy - Building video video/EVAL_CarRacing-v2_ep_412.mp4.
# Moviepy - Writing video video/EVAL_CarRacing-v2_ep_412.mp4
# Moviepy - Done !
# Moviepy - video ready video/EVAL_CarRacing-v2_ep_412.mp4
# Target run, ep. 412. Steps: 1000  Reward: -39.6. Tiles opened: 15.0. Gone out: 0.0
# Model saved to ./models/model_ep_412_rew_111.pth
# Worker 6 finished episode 413. Reward -33. LR=[1e-05]
# Worker 7 finished episode 414. Reward -17. LR=[1e-05]
# Worker 5 finished episode 415. Reward -26. LR=[1e-05]
# Worker 4 finished episode 416. Reward -59. LR=[1e-05]
# Worker 2 finished episode 417. Reward -72. LR=[1e-05]
# Worker 0 finished episode 418. Reward 26. LR=[1e-05]
# Worker 3 finished episode 419. Reward -63. LR=[1e-05]
# Worker 1 finished episode 420. Reward -21. LR=[1e-05]
# Worker 6 finished episode 421. Reward -34. LR=[1e-05]
# Worker 7 finished episode 422. Reward -25. LR=[1e-05]
# Worker 5 finished episode 423. Reward -30. LR=[1e-05]
# Worker 4 finished episode 424. Reward -44. LR=[1e-05]
# Worker 0 finished episode 425. Reward -16. LR=[1e-05]
# Worker 2 finished episode 426. Reward 48. LR=[1e-05]
# Worker 3 finished episode 427. Reward -37. LR=[1e-05]
# Worker 1 finished episode 428. Reward -21. LR=[1e-05]
# Worker 6 finished episode 429. Reward 48. LR=[1e-05]
# Worker 7 finished episode 430. Reward -27. LR=[1e-05]
# Worker 5 finished episode 431. Reward -38. LR=[1e-05]
# Worker 4 finished episode 432. Reward -36. LR=[1e-05]
# Worker 2 finished episode 433. Reward 18. LR=[1e-05]
# Worker 3 finished episode 434. Reward -58. LR=[1e-05]
# Worker 0 finished episode 435. Reward 16. LR=[1e-05]
# Worker 1 finished episode 436. Reward -24. LR=[1e-05]
# Worker 6 finished episode 437. Reward 25. LR=[1e-05]
# Worker 7 finished episode 438. Reward -55. LR=[1e-05]
# Worker 4 finished episode 439. Reward -38. LR=[1e-05]
# Worker 5 finished episode 440. Reward -61. LR=[1e-05]
# Worker 2 finished episode 441. Reward 16. LR=[1e-05]
# Worker 3 finished episode 442. Reward -40. LR=[1e-05]
# Worker 0 finished episode 443. Reward -52. LR=[1e-05]
# Worker 1 finished episode 444. Reward -35. LR=[1e-05]
# Worker 6 finished episode 445. Reward -31. LR=[1e-05]
# Worker 7 finished episode 446. Reward -41. LR=[1e-05]
# Worker 4 finished episode 447. Reward -19. LR=[1e-05]
# Worker 5 finished episode 448. Reward 109. LR=[1e-05]
# Worker 2 finished episode 449. Reward 78. LR=[1e-05]
# Worker 0 finished episode 450. Reward -34. LR=[1e-05]
# Worker 3 finished episode 451. Reward -45. LR=[1e-05]
# Worker 1 finished episode 452. Reward -35. LR=[1e-05]
# Worker 6 finished episode 453. Reward -5. LR=[1e-05]
# Worker 7 finished episode 454. Reward -35. LR=[1e-05]
# Worker 5 finished episode 455. Reward 77. LR=[1e-05]
# Worker 4 finished episode 456. Reward 78. LR=[1e-05]
# Worker 2 finished episode 457. Reward -77. LR=[1e-05]
# Worker 1 finished episode 458. Reward 25. LR=[1e-05]
# Worker 0 finished episode 459. Reward 45. LR=[1e-05]
# Worker 3 finished episode 460. Reward -48. LR=[1e-05]
# Worker 6 finished episode 461. Reward -63. LR=[1e-05]
# Worker 7 finished episode 462. Reward 163. LR=[1e-05]
# New best episode reward 163. Evaluating worker network, saving video and checkpoint
# Moviepy - Building video video/EVAL_CarRacing-v2_ep_462.mp4.
# Moviepy - Writing video video/EVAL_CarRacing-v2_ep_462.mp4
# Moviepy - Done !
# Moviepy - video ready video/EVAL_CarRacing-v2_ep_462.mp4
# Target run, ep. 462. Steps: 1000  Reward: 36.5. Tiles opened: 38.0. Gone out: 0.0
# Model saved to ./models/model_ep_462_rew_163.pth
# Worker 4 finished episode 463. Reward 115. LR=[1e-05]
# Worker 5 finished episode 464. Reward -39. LR=[1e-05]
# Worker 2 finished episode 465. Reward -35. LR=[1e-05]
# Worker 1 finished episode 466. Reward 42. LR=[1e-05]
# Worker 3 finished episode 467. Reward -22. LR=[1e-05]
# Worker 0 finished episode 468. Reward 151. LR=[1e-05]
# Worker 6 finished episode 469. Reward -36. LR=[1e-05]
# Worker 7 finished episode 470. Reward 63. LR=[1e-05]
# Worker 4 finished episode 471. Reward -35. LR=[1e-05]
# Worker 5 finished episode 472. Reward -53. LR=[1e-05]
# Worker 2 finished episode 473. Reward 67. LR=[1e-05]
# Worker 1 finished episode 474. Reward -34. LR=[1e-05]
# Worker 3 finished episode 475. Reward 25. LR=[1e-05]
# Worker 0 finished episode 476. Reward -29. LR=[1e-05]
# Worker 6 finished episode 477. Reward -42. LR=[1e-05]
# Worker 7 finished episode 478. Reward 70. LR=[1e-05]
# Worker 4 finished episode 479. Reward -66. LR=[1e-05]
# Worker 5 finished episode 480. Reward 22. LR=[1e-05]
# Worker 2 finished episode 481. Reward -31. LR=[1e-05]
# Worker 3 finished episode 482. Reward 58. LR=[1e-05]
# Worker 1 finished episode 483. Reward -3. LR=[1e-05]
# Worker 0 finished episode 484. Reward -68. LR=[1e-05]
# Worker 6 finished episode 485. Reward 21. LR=[1e-05]
# Worker 7 finished episode 486. Reward 59. LR=[1e-05]
# Worker 4 finished episode 487. Reward 89. LR=[1e-05]
# Worker 5 finished episode 488. Reward -37. LR=[1e-05]
# Worker 2 finished episode 489. Reward 111. LR=[1e-05]
# Worker 3 finished episode 490. Reward -3. LR=[1e-05]
# Worker 1 finished episode 491. Reward 49. LR=[1e-05]
# Worker 0 finished episode 492. Reward 38. LR=[1e-05]
# Worker 6 finished episode 493. Reward 27. LR=[1e-05]
# Worker 7 finished episode 494. Reward 145. LR=[1e-05]
# Worker 5 finished episode 495. Reward 112. LR=[1e-05]
# Worker 4 finished episode 496. Reward 60. LR=[1e-05]
# Worker 2 finished episode 497. Reward 47. LR=[1e-05]
# Worker 3 finished episode 498. Reward 24. LR=[1e-05]
# Worker 1 finished episode 499. Reward -39. LR=[1e-05]
# Worker 0 finished episode 500. Reward 62. LR=[1e-05]
# Worker 6 finished episode 501. Reward -28. LR=[1e-05]
# Worker 7 finished episode 502. Reward -35. LR=[1e-05]
# Worker 5 finished episode 503. Reward -19. LR=[1e-05]
# Worker 4 finished episode 504. Reward 62. LR=[1e-05]
# Worker 2 finished episode 505. Reward 258. LR=[1e-05]
# New best episode reward 258. Evaluating worker network, saving video and checkpoint
# Moviepy - Building video video/EVAL_CarRacing-v2_ep_505.mp4.
# Moviepy - Writing video video/EVAL_CarRacing-v2_ep_505.mp4
# Moviepy - Done !
# Moviepy - video ready video/EVAL_CarRacing-v2_ep_505.mp4
# Target run, ep. 505. Steps: 1000  Reward: 31.1. Tiles opened: 29.0. Gone out: 0.0
# Model saved to ./models/model_ep_505_rew_258.pth
# Worker 3 finished episode 506. Reward -42. LR=[1e-05]
# Worker 1 finished episode 507. Reward 121. LR=[1e-05]
# Worker 0 finished episode 508. Reward 8. LR=[1e-05]
# Worker 6 finished episode 509. Reward 23. LR=[1e-05]
# Worker 7 finished episode 510. Reward 254. LR=[1e-05]
# Worker 5 finished episode 511. Reward 15. LR=[1e-05]
# Worker 4 finished episode 512. Reward 98. LR=[1e-05]
# Worker 2 finished episode 513. Reward -39. LR=[1e-05]
# Worker 1 finished episode 514. Reward -2. LR=[1e-05]
# Worker 3 finished episode 515. Reward -28. LR=[1e-05]
# Worker 0 finished episode 516. Reward -36. LR=[1e-05]
# Worker 6 finished episode 517. Reward 94. LR=[1e-05]
# Worker 7 finished episode 518. Reward 60. LR=[1e-05]
# Worker 5 finished episode 519. Reward 53. LR=[1e-05]
# Worker 4 finished episode 520. Reward 6. LR=[1e-05]
# Worker 2 finished episode 521. Reward 16. LR=[1e-05]
# Worker 3 finished episode 522. Reward 166. LR=[1e-05]
# Worker 1 finished episode 523. Reward -58. LR=[1e-05]
# Worker 0 finished episode 524. Reward -72. LR=[1e-05]
# Worker 6 finished episode 525. Reward 336. LR=[1e-05]
# New best episode reward 336. Evaluating worker network, saving video and checkpoint
# Moviepy - Building video video/EVAL_CarRacing-v2_ep_525.mp4.
# Moviepy - Writing video video/EVAL_CarRacing-v2_ep_525.mp4
# Moviepy - Done !
# Moviepy - video ready video/EVAL_CarRacing-v2_ep_525.mp4
# Target run, ep. 525. Steps: 1000  Reward: 71.1. Tiles opened: 53.0. Gone out: 0.0
# Model saved to ./models/model_ep_525_rew_336.pth
# Worker 7 finished episode 526. Reward -68. LR=[1e-05]
# Worker 5 finished episode 527. Reward 115. LR=[1e-05]
# Worker 4 finished episode 528. Reward 207. LR=[1e-05]
# Worker 2 finished episode 529. Reward 42. LR=[1e-05]
# Worker 1 finished episode 530. Reward 163. LR=[1e-05]
# Worker 3 finished episode 531. Reward 39. LR=[1e-05]
# Worker 0 finished episode 532. Reward 49. LR=[1e-05]
# Worker 6 finished episode 533. Reward -22. LR=[1e-05]
# Worker 5 finished episode 534. Reward 72. LR=[1e-05]
# Worker 7 finished episode 535. Reward 137. LR=[1e-05]
# Worker 4 finished episode 536. Reward 277. LR=[1e-05]
# Worker 2 finished episode 537. Reward 58. LR=[1e-05]
# Worker 1 finished episode 538. Reward 190. LR=[1e-05]
# Worker 3 finished episode 539. Reward -36. LR=[1e-05]
# Worker 0 finished episode 540. Reward 1. LR=[1e-05]
# Worker 6 finished episode 541. Reward 113. LR=[1e-05]
# Worker 5 finished episode 542. Reward 195. LR=[1e-05]
# Worker 7 finished episode 543. Reward 200. LR=[1e-05]
# Worker 4 finished episode 544. Reward 164. LR=[1e-05]
# Worker 2 finished episode 545. Reward 224. LR=[1e-05]
# Worker 1 finished episode 546. Reward 195. LR=[1e-05]
# Worker 3 finished episode 547. Reward 29. LR=[1e-05]
# Worker 0 finished episode 548. Reward 58. LR=[1e-05]
# Worker 6 finished episode 549. Reward 78. LR=[1e-05]
# Worker 5 finished episode 550. Reward 212. LR=[1e-05]
# Worker 7 finished episode 551. Reward -38. LR=[1e-05]
# Worker 4 finished episode 552. Reward 21. LR=[1e-05]
# Worker 2 finished episode 553. Reward 39. LR=[1e-05]
# Worker 1 finished episode 554. Reward 166. LR=[1e-05]
# Worker 3 finished episode 555. Reward 126. LR=[1e-05]
# Worker 6 finished episode 556. Reward 190. LR=[1e-05]
# Worker 0 finished episode 557. Reward 149. LR=[1e-05]
# Worker 5 finished episode 558. Reward 40. LR=[1e-05]
# Worker 7 finished episode 559. Reward 5. LR=[1e-05]
# Worker 4 finished episode 560. Reward 56. LR=[1e-05]
# Worker 2 finished episode 561. Reward 173. LR=[1e-05]
# Worker 1 finished episode 562. Reward 97. LR=[1e-05]
# Worker 3 finished episode 563. Reward -32. LR=[1e-05]
# Worker 6 finished episode 564. Reward -21. LR=[1e-05]
# Worker 0 finished episode 565. Reward 116. LR=[1e-05]
# Worker 7 finished episode 566. Reward 87. LR=[1e-05]
# Worker 5 finished episode 567. Reward 188. LR=[1e-05]
# Worker 4 finished episode 568. Reward 70. LR=[1e-05]
# Worker 2 finished episode 569. Reward 185. LR=[1e-05]
# Worker 1 finished episode 570. Reward 62. LR=[1e-05]
# Worker 3 finished episode 571. Reward 262. LR=[1e-05]
# Worker 0 finished episode 572. Reward 72. LR=[1e-05]
# Worker 6 finished episode 573. Reward 195. LR=[1e-05]
# Worker 7 finished episode 574. Reward 159. LR=[1e-05]
# Worker 4 finished episode 575. Reward 54. LR=[1e-05]
# Worker 5 finished episode 576. Reward 176. LR=[1e-05]
# Worker 1 finished episode 577. Reward 231. LR=[1e-05]
# Worker 2 finished episode 578. Reward 519. LR=[1e-05]
# New best episode reward 519. Evaluating worker network, saving video and checkpoint
# Moviepy - Building video video/EVAL_CarRacing-v2_ep_578.mp4.
# Moviepy - Writing video video/EVAL_CarRacing-v2_ep_578.mp4
# Moviepy - Done !
# Moviepy - video ready video/EVAL_CarRacing-v2_ep_578.mp4
# Target run, ep. 578. Steps: 1000  Reward: -15.5. Tiles opened: 21.0. Gone out: 0.0
# Model saved to ./models/model_ep_578_rew_519.pth
# Worker 3 finished episode 579. Reward 92. LR=[1e-05]
# Worker 0 finished episode 580. Reward 88. LR=[1e-05]
# Worker 6 finished episode 581. Reward 36. LR=[1e-05]
# Worker 4 finished episode 582. Reward 242. LR=[1e-05]
# Worker 7 finished episode 583. Reward 18. LR=[1e-05]
# Worker 5 finished episode 584. Reward 173. LR=[1e-05]
# Worker 2 finished episode 585. Reward 56. LR=[1e-05]
# Worker 3 finished episode 586. Reward 63. LR=[1e-05]
# Worker 1 finished episode 587. Reward 92. LR=[1e-05]
# Worker 6 finished episode 588. Reward 143. LR=[1e-05]
# Worker 0 finished episode 589. Reward 25. LR=[1e-05]
# Worker 4 finished episode 590. Reward 150. LR=[1e-05]
# Worker 7 finished episode 591. Reward 36. LR=[1e-05]
# Worker 5 finished episode 592. Reward 242. LR=[1e-05]
# Worker 2 finished episode 593. Reward 173. LR=[1e-05]
# Worker 3 finished episode 594. Reward 282. LR=[1e-05]
# Worker 0 finished episode 595. Reward 139. LR=[1e-05]
# Worker 6 finished episode 596. Reward 174. LR=[1e-05]
# Worker 1 finished episode 597. Reward 248. LR=[1e-05]
# Worker 7 finished episode 598. Reward 29. LR=[1e-05]
# Worker 4 finished episode 599. Reward 230. LR=[1e-05]
# Worker 5 finished episode 600. Reward 8. LR=[1e-05]
# Worker 2 finished episode 601. Reward 139. LR=[1e-05]
# Worker 3 finished episode 602. Reward 139. LR=[1e-05]
# Worker 0 finished episode 603. Reward 109. LR=[1e-05]
# Worker 1 finished episode 604. Reward 109. LR=[1e-05]
# Worker 6 finished episode 605. Reward 280. LR=[1e-05]
# Worker 7 finished episode 606. Reward 63. LR=[1e-05]
# Worker 4 finished episode 607. Reward 120. LR=[1e-05]
# Worker 5 finished episode 608. Reward 291. LR=[1e-05]
# Worker 2 finished episode 609. Reward 178. LR=[1e-05]
# Worker 0 finished episode 610. Reward 175. LR=[1e-05]
# Worker 1 finished episode 611. Reward 175. LR=[1e-05]
# Worker 3 finished episode 612. Reward 174. LR=[1e-05]
# Worker 6 finished episode 613. Reward 128. LR=[1e-05]
# Worker 7 finished episode 614. Reward 131. LR=[1e-05]
# Worker 4 finished episode 615. Reward 173. LR=[1e-05]
# Worker 5 finished episode 616. Reward 205. LR=[1e-05]
# Worker 2 finished episode 617. Reward -12. LR=[1e-05]
# Worker 0 finished episode 618. Reward 162. LR=[1e-05]
# Worker 1 finished episode 619. Reward 310. LR=[1e-05]
# Worker 3 finished episode 620. Reward 24. LR=[1e-05]
# Worker 6 finished episode 621. Reward 177. LR=[1e-05]
# Worker 7 finished episode 622. Reward 119. LR=[1e-05]
# Worker 4 finished episode 623. Reward 489. LR=[1e-05]
# Worker 5 finished episode 624. Reward 111. LR=[1e-05]
# Worker 2 finished episode 625. Reward 61. LR=[1e-05]
# Worker 0 finished episode 626. Reward 207. LR=[1e-05]
# Worker 1 finished episode 627. Reward 3. LR=[1e-05]
# Worker 3 finished episode 628. Reward 127. LR=[1e-05]
# Worker 6 finished episode 629. Reward 21. LR=[1e-05]
# Worker 7 finished episode 630. Reward 162. LR=[1e-05]
# Worker 4 finished episode 631. Reward 46. LR=[1e-05]
# Worker 5 finished episode 632. Reward 106. LR=[1e-05]
# Worker 2 finished episode 633. Reward 129. LR=[1e-05]
# Worker 0 finished episode 634. Reward 294. LR=[1e-05]
# Worker 1 finished episode 635. Reward 160. LR=[1e-05]
# Worker 3 finished episode 636. Reward 165. LR=[1e-05]
# Worker 6 finished episode 637. Reward 186. LR=[1e-05]
# Worker 4 finished episode 638. Reward -36. LR=[1e-05]
# Worker 7 finished episode 639. Reward 157. LR=[1e-05]
# Worker 5 finished episode 640. Reward 158. LR=[1e-05]
# Worker 2 finished episode 641. Reward -19. LR=[1e-05]
# Worker 0 finished episode 642. Reward 158. LR=[1e-05]
# Worker 1 finished episode 643. Reward 157. LR=[1e-05]
# Worker 3 finished episode 644. Reward 196. LR=[1e-05]
# Worker 6 finished episode 645. Reward 185. LR=[1e-05]
# Worker 4 finished episode 646. Reward 42. LR=[1e-05]
# Worker 7 finished episode 647. Reward 41. LR=[1e-05]
# Worker 5 finished episode 648. Reward 87. LR=[1e-05]
# Worker 2 finished episode 649. Reward 169. LR=[1e-05]
# Worker 0 finished episode 650. Reward 195. LR=[1e-05]
# Worker 3 finished episode 651. Reward 198. LR=[1e-05]
# Worker 1 finished episode 652. Reward -6. LR=[1e-05]
# Worker 6 finished episode 653. Reward 106. LR=[1e-05]
# Worker 4 finished episode 654. Reward 175. LR=[1e-05]
# Worker 7 finished episode 655. Reward 206. LR=[1e-05]
# Worker 5 finished episode 656. Reward 74. LR=[1e-05]
# Worker 2 finished episode 657. Reward 165. LR=[1e-05]
# Worker 0 finished episode 658. Reward 137. LR=[1e-05]
# Worker 3 finished episode 659. Reward 246. LR=[1e-05]
# Worker 1 finished episode 660. Reward 86. LR=[1e-05]
# Worker 6 finished episode 661. Reward 55. LR=[1e-05]
# Worker 4 finished episode 662. Reward 11. LR=[1e-05]
# Worker 7 finished episode 663. Reward 26. LR=[1e-05]
# Worker 5 finished episode 664. Reward 279. LR=[1e-05]
# Worker 2 finished episode 665. Reward 113. LR=[1e-05]
# Worker 0 finished episode 666. Reward 39. LR=[1e-05]
# Worker 3 finished episode 667. Reward 144. LR=[1e-05]
# Worker 1 finished episode 668. Reward 25. LR=[1e-05]
# Worker 6 finished episode 669. Reward 194. LR=[1e-05]
# Worker 4 finished episode 670. Reward 115. LR=[1e-05]
# Worker 7 finished episode 671. Reward 214. LR=[1e-05]
# Worker 5 finished episode 672. Reward 8. LR=[1e-05]
# Worker 2 finished episode 673. Reward 143. LR=[1e-05]
# Worker 0 finished episode 674. Reward 141. LR=[1e-05]
# Worker 3 finished episode 675. Reward 221. LR=[1e-05]
# Worker 1 finished episode 676. Reward 80. LR=[1e-05]
# Worker 6 finished episode 677. Reward 301. LR=[1e-05]
# Worker 4 finished episode 678. Reward 221. LR=[1e-05]
# Worker 7 finished episode 679. Reward 220. LR=[1e-05]
# Worker 5 finished episode 680. Reward 50. LR=[1e-05]
# Worker 2 finished episode 681. Reward 185. LR=[1e-05]
# Worker 0 finished episode 682. Reward 354. LR=[1e-05]
# Worker 1 finished episode 683. Reward 212. LR=[1e-05]
# Worker 3 finished episode 684. Reward 130. LR=[1e-05]
# Worker 6 finished episode 685. Reward 78. LR=[1e-05]
# Worker 4 finished episode 686. Reward -26. LR=[1e-05]
# Worker 7 finished episode 687. Reward -54. LR=[1e-05]
# Worker 5 finished episode 688. Reward 148. LR=[1e-05]
# Worker 2 finished episode 689. Reward 144. LR=[1e-05]
# Worker 1 finished episode 690. Reward 30. LR=[1e-05]
# Worker 0 finished episode 691. Reward 195. LR=[1e-05]
# Worker 3 finished episode 692. Reward 146. LR=[1e-05]
# Worker 6 finished episode 693. Reward 167. LR=[1e-05]
# Worker 4 finished episode 694. Reward 140. LR=[1e-05]
# Worker 7 finished episode 695. Reward 56. LR=[1e-05]
# Worker 5 finished episode 696. Reward 237. LR=[1e-05]
# Worker 2 finished episode 697. Reward 207. LR=[1e-05]
# Worker 0 finished episode 698. Reward 129. LR=[1e-05]
# Worker 1 finished episode 699. Reward 272. LR=[1e-05]
# Worker 3 finished episode 700. Reward 328. LR=[1e-05]
# Worker 6 finished episode 701. Reward 153. LR=[1e-05]
# Worker 4 finished episode 702. Reward 132. LR=[1e-05]
# Worker 7 finished episode 703. Reward 136. LR=[1e-05]
# Worker 5 finished episode 704. Reward 116. LR=[1e-05]
# Worker 2 finished episode 705. Reward -7. LR=[1e-05]
# Worker 0 finished episode 706. Reward 89. LR=[1e-05]
# Worker 1 finished episode 707. Reward 73. LR=[1e-05]
# Worker 3 finished episode 708. Reward 91. LR=[1e-05]
# Worker 6 finished episode 709. Reward 146. LR=[1e-05]
# Worker 4 finished episode 710. Reward 235. LR=[1e-05]
# Worker 7 finished episode 711. Reward 359. LR=[1e-05]
# Worker 5 finished episode 712. Reward 228. LR=[1e-05]
# Worker 2 finished episode 713. Reward 96. LR=[1e-05]
# Worker 1 finished episode 714. Reward 92. LR=[1e-05]
# Worker 0 finished episode 715. Reward 37. LR=[1e-05]
# Worker 3 finished episode 716. Reward 158. LR=[1e-05]
# Worker 6 finished episode 717. Reward 224. LR=[1e-05]
# Worker 4 finished episode 718. Reward 265. LR=[1e-05]
# Worker 7 finished episode 719. Reward 350. LR=[1e-05]
# Worker 5 finished episode 720. Reward -11. LR=[1e-05]
# Worker 2 finished episode 721. Reward 21. LR=[1e-05]
# Worker 1 finished episode 722. Reward 162. LR=[1e-05]
# Worker 3 finished episode 723. Reward 235. LR=[1e-05]
# Worker 4 finished episode 724. Reward 171. LR=[1e-05]
# Worker 0 finished episode 725. Reward 178. LR=[1e-05]
# Worker 6 finished episode 726. Reward 109. LR=[1e-05]
# Worker 7 finished episode 727. Reward 254. LR=[1e-05]
# Worker 5 finished episode 728. Reward 325. LR=[1e-05]
# Worker 1 finished episode 729. Reward 236. LR=[1e-05]
# Worker 2 finished episode 730. Reward 119. LR=[1e-05]
# Worker 3 finished episode 731. Reward 218. LR=[1e-05]
# Worker 0 finished episode 732. Reward 135. LR=[1e-05]
# Worker 4 finished episode 733. Reward 125. LR=[1e-05]
# Worker 6 finished episode 734. Reward 66. LR=[1e-05]
# Worker 7 finished episode 735. Reward 210. LR=[1e-05]
# Worker 5 finished episode 736. Reward 286. LR=[1e-05]
# Worker 1 finished episode 737. Reward 238. LR=[1e-05]
# Worker 2 finished episode 738. Reward 198. LR=[1e-05]
# Worker 0 finished episode 739. Reward 37. LR=[1e-05]
# Worker 4 finished episode 740. Reward 142. LR=[1e-05]
# Worker 3 finished episode 741. Reward 313. LR=[1e-05]
# Worker 6 finished episode 742. Reward 121. LR=[1e-05]
# Worker 7 finished episode 743. Reward 278. LR=[1e-05]
# Worker 5 finished episode 744. Reward 92. LR=[1e-05]
# Worker 1 finished episode 745. Reward 28. LR=[1e-05]
# Worker 0 finished episode 746. Reward 230. LR=[1e-05]
# Worker 2 finished episode 747. Reward 196. LR=[1e-05]
# Worker 3 finished episode 748. Reward 284. LR=[1e-05]
# Worker 4 finished episode 749. Reward 313. LR=[1e-05]
# Worker 6 finished episode 750. Reward 155. LR=[1e-05]
# Worker 7 finished episode 751. Reward 115. LR=[1e-05]
# Worker 5 finished episode 752. Reward 132. LR=[1e-05]
# Worker 1 finished episode 753. Reward 184. LR=[1e-05]
# Worker 4 finished episode 754. Reward 195. LR=[1e-05]
# Worker 2 finished episode 755. Reward 201. LR=[1e-05]
# Worker 3 finished episode 756. Reward 47. LR=[1e-05]
# Worker 0 finished episode 757. Reward 417. LR=[1e-05]
# Worker 6 finished episode 758. Reward 249. LR=[1e-05]
# Worker 7 finished episode 759. Reward -39. LR=[1e-05]
# Worker 5 finished episode 760. Reward 174. LR=[1e-05]
# Worker 1 finished episode 761. Reward 121. LR=[1e-05]
# Worker 3 finished episode 762. Reward 236. LR=[1e-05]
# Worker 4 finished episode 763. Reward 185. LR=[1e-05]
# Worker 0 finished episode 764. Reward 459. LR=[1e-05]
# Worker 2 finished episode 765. Reward 391. LR=[1e-05]
# Worker 6 finished episode 766. Reward 71. LR=[1e-05]
# Worker 7 finished episode 767. Reward 102. LR=[1e-05]
# Worker 5 finished episode 768. Reward 222. LR=[1e-05]
# Worker 1 finished episode 769. Reward 234. LR=[1e-05]
# Worker 3 finished episode 770. Reward 156. LR=[1e-05]
# Worker 0 finished episode 771. Reward 186. LR=[1e-05]
# Worker 2 finished episode 772. Reward 259. LR=[1e-05]
# Worker 4 finished episode 773. Reward 489. LR=[1e-05]
# Worker 6 finished episode 774. Reward 368. LR=[1e-05]
# Worker 7 finished episode 775. Reward 334. LR=[1e-05]
# Worker 5 finished episode 776. Reward 304. LR=[1e-05]
# Worker 1 finished episode 777. Reward 315. LR=[1e-05]
# Worker 3 finished episode 778. Reward 176. LR=[1e-05]
# Worker 4 finished episode 779. Reward 255. LR=[1e-05]
# Worker 0 finished episode 780. Reward 451. LR=[1e-05]
# Worker 2 finished episode 781. Reward 357. LR=[1e-05]
# Worker 6 finished episode 782. Reward 293. LR=[1e-05]
# Worker 7 finished episode 783. Reward 162. LR=[1e-05]
# Worker 5 finished episode 784. Reward 235. LR=[1e-05]
# Worker 1 finished episode 785. Reward 62. LR=[1e-05]
# Worker 3 finished episode 786. Reward 84. LR=[1e-05]
# Worker 0 finished episode 787. Reward 317. LR=[1e-05]
# Worker 4 finished episode 788. Reward 61. LR=[1e-05]
# Worker 6 finished episode 789. Reward 298. LR=[1e-05]
# Worker 2 finished episode 790. Reward 388. LR=[1e-05]
# Worker 7 finished episode 791. Reward 122. LR=[1e-05]
# Worker 5 finished episode 792. Reward 309. LR=[1e-05]
# Worker 1 finished episode 793. Reward 186. LR=[1e-05]
# Worker 3 finished episode 794. Reward 259. LR=[1e-05]
# Worker 0 finished episode 795. Reward 29. LR=[1e-05]
# Worker 4 finished episode 796. Reward 244. LR=[1e-05]
# Worker 6 finished episode 797. Reward 182. LR=[1e-05]
# Worker 2 finished episode 798. Reward 325. LR=[1e-05]
# Worker 7 finished episode 799. Reward 179. LR=[1e-05]
# Worker 5 finished episode 800. Reward 298. LR=[1e-05]
# Worker 1 finished episode 801. Reward 322. LR=[1e-05]
# Worker 3 finished episode 802. Reward 69. LR=[1e-05]
# Worker 4 finished episode 803. Reward 719. LR=[1e-05]
# New best episode reward 719. Evaluating worker network, saving video and checkpoint
# Moviepy - Building video video/EVAL_CarRacing-v2_ep_803.mp4.
# Moviepy - Writing video video/EVAL_CarRacing-v2_ep_803.mp4
# Moviepy - Done !
# Moviepy - video ready video/EVAL_CarRacing-v2_ep_803.mp4
# Target run, ep. 803. Steps: 1000  Reward: -10.9. Tiles opened: 25.0. Gone out: 0.0
# Model saved to ./models/model_ep_803_rew_719.pth
# Worker 0 finished episode 804. Reward 177. LR=[1e-05]
# Worker 2 finished episode 805. Reward 242. LR=[1e-05]
# Worker 6 finished episode 806. Reward 337. LR=[1e-05]
# Worker 7 finished episode 807. Reward 184. LR=[1e-05]
# Worker 5 finished episode 808. Reward 291. LR=[1e-05]
# Worker 1 finished episode 809. Reward 195. LR=[1e-05]
# Worker 3 finished episode 810. Reward 185. LR=[1e-05]
# Worker 4 finished episode 811. Reward 507. LR=[1e-05]
# Worker 0 finished episode 812. Reward 175. LR=[1e-05]
# Worker 6 finished episode 813. Reward 269. LR=[1e-05]
# Worker 2 finished episode 814. Reward 438. LR=[1e-05]
# Worker 7 finished episode 815. Reward 481. LR=[1e-05]
# Worker 5 finished episode 816. Reward 195. LR=[1e-05]
# Worker 1 finished episode 817. Reward 144. LR=[1e-05]
# Worker 3 finished episode 818. Reward 210. LR=[1e-05]
# Worker 6 finished episode 819. Reward 315. LR=[1e-05]
# Worker 4 finished episode 820. Reward 446. LR=[1e-05]
# Worker 0 finished episode 821. Reward 493. LR=[1e-05]
# Worker 2 finished episode 822. Reward 314. LR=[1e-05]
# Worker 7 finished episode 823. Reward 23. LR=[1e-05]
# Worker 5 finished episode 824. Reward 387. LR=[1e-05]
# Worker 1 finished episode 825. Reward 239. LR=[1e-05]
# Worker 3 finished episode 826. Reward 141. LR=[1e-05]
# Worker 6 finished episode 827. Reward 281. LR=[1e-05]
# Worker 0 finished episode 828. Reward 185. LR=[1e-05]
# Worker 2 finished episode 829. Reward 133. LR=[1e-05]
# Worker 4 finished episode 830. Reward 469. LR=[1e-05]
# Worker 7 finished episode 831. Reward 210. LR=[1e-05]
# Worker 5 finished episode 832. Reward 170. LR=[1e-05]
# Worker 1 finished episode 833. Reward 287. LR=[1e-05]
# Worker 3 finished episode 834. Reward 122. LR=[1e-05]
# Worker 4 finished episode 835. Reward 297. LR=[1e-05]
# Worker 0 finished episode 836. Reward 393. LR=[1e-05]
# Worker 6 finished episode 837. Reward 195. LR=[1e-05]
# Worker 2 finished episode 838. Reward 322. LR=[1e-05]
# Worker 7 finished episode 839. Reward 180. LR=[1e-05]
# Worker 5 finished episode 840. Reward 148. LR=[1e-05]
# Worker 1 finished episode 841. Reward 156. LR=[1e-05]
# Worker 3 finished episode 842. Reward 457. LR=[1e-05]
# Worker 4 finished episode 843. Reward 233. LR=[1e-05]
# Worker 6 finished episode 844. Reward 338. LR=[1e-05]
# Worker 0 finished episode 845. Reward 245. LR=[1e-05]
# ...
# Worker 1 finished episode 4314. Reward 785. LR=[1e-05]
# Worker 4 finished episode 4315. Reward 788. LR=[1e-05]
# Worker 6 finished episode 4316. Reward 647. LR=[1e-05]
# Worker 5 finished episode 4317. Reward 534. LR=[1e-05]
# Worker 0 finished episode 4318. Reward 719. LR=[1e-05]
# Worker 7 finished episode 4319. Reward 296. LR=[1e-05]
# Worker 2 finished episode 4320. Reward 691. LR=[1e-05]
# Worker 3 finished episode 4321. Reward 595. LR=[1e-05]
# Worker 1 finished episode 4322. Reward 695. LR=[1e-05]
# Worker 4 finished episode 4323. Reward 553. LR=[1e-05]
# Worker 6 finished episode 4324. Reward 250. LR=[1e-05]
# Worker 5 finished episode 4325. Reward 713. LR=[1e-05]
# Worker 0 finished episode 4326. Reward 435. LR=[1e-05]
# Worker 7 finished episode 4327. Reward 677. LR=[1e-05]
# Worker 2 finished episode 4328. Reward 743. LR=[1e-05]
# Worker 3 finished episode 4329. Reward 855. LR=[1e-05]
# Worker 1 finished episode 4330. Reward 640. LR=[1e-05]
# Worker 4 finished episode 4331. Reward 536. LR=[1e-05]
# Worker 6 finished episode 4332. Reward 687. LR=[1e-05]
# Worker 0 finished episode 4333. Reward 589. LR=[1e-05]
# Worker 5 finished episode 4334. Reward 618. LR=[1e-05]
# Worker 7 finished episode 4335. Reward 218. LR=[1e-05]
# Worker 2 finished episode 4336. Reward 308. LR=[1e-05]
# Worker 3 finished episode 4337. Reward 657. LR=[1e-05]
# Worker 1 finished episode 4338. Reward 750. LR=[1e-05]
# Worker 4 finished episode 4339. Reward 737. LR=[1e-05]
# Worker 6 finished episode 4340. Reward 780. LR=[1e-05]
# Worker 0 finished episode 4341. Reward 793. LR=[1e-05]
# Worker 5 finished episode 4342. Reward 774. LR=[1e-05]
# Worker 7 finished episode 4343. Reward 637. LR=[1e-05]
# Worker 2 finished episode 4344. Reward 463. LR=[1e-05]
# Worker 3 finished episode 4345. Reward 520. LR=[1e-05]
# Worker 1 finished episode 4346. Reward 778. LR=[1e-05]
# Worker 4 finished episode 4347. Reward 686. LR=[1e-05]
# Worker 6 finished episode 4348. Reward 627. LR=[1e-05]
# Worker 0 finished episode 4349. Reward 472. LR=[1e-05]
# Worker 5 finished episode 4350. Reward 870. LR=[1e-05]
# Worker 7 finished episode 4351. Reward 645. LR=[1e-05]
# Worker 2 finished episode 4352. Reward 837. LR=[1e-05]
# Worker 3 finished episode 4353. Reward 391. LR=[1e-05]
# Worker 4 finished episode 4354. Reward 722. LR=[1e-05]
# Worker 1 finished episode 4355. Reward 432. LR=[1e-05]
# Worker 6 finished episode 4356. Reward 753. LR=[1e-05]
# Worker 0 finished episode 4357. Reward 744. LR=[1e-05]
# Worker 5 finished episode 4358. Reward 391. LR=[1e-05]
# Worker 7 finished episode 4359. Reward 395. LR=[1e-05]
# Worker 2 finished episode 4360. Reward 860. LR=[1e-05]
# Worker 3 finished episode 4361. Reward 817. LR=[1e-05]
# Worker 4 finished episode 4362. Reward 335. LR=[1e-05]
# Worker 1 finished episode 4363. Reward 393. LR=[1e-05]
# Worker 6 finished episode 4364. Reward 217. LR=[1e-05]
# Worker 0 finished episode 4365. Reward 850. LR=[1e-05]
# Worker 5 finished episode 4366. Reward 535. LR=[1e-05]
# Worker 2 finished episode 4367. Reward 257. LR=[1e-05]
# Worker 7 finished episode 4368. Reward 583. LR=[1e-05]
# Worker 3 finished episode 4369. Reward 567. LR=[1e-05]
# Worker 4 finished episode 4370. Reward 478. LR=[1e-05]
# Worker 1 finished episode 4371. Reward 294. LR=[1e-05]
# Worker 6 finished episode 4372. Reward 765. LR=[1e-05]
# Worker 5 finished episode 4373. Reward 864. LR=[1e-05]
# Worker 0 finished episode 4374. Reward 689. LR=[1e-05]
# Worker 7 finished episode 4375. Reward 772. LR=[1e-05]
# Worker 3 finished episode 4376. Reward 749. LR=[1e-05]
# Worker 2 finished episode 4377. Reward 440. LR=[1e-05]
# Worker 4 finished episode 4378. Reward 402. LR=[1e-05]
# Worker 6 finished episode 4379. Reward 315. LR=[1e-05]
# Worker 1 finished episode 4380. Reward 757. LR=[1e-05]
# Worker 5 finished episode 4381. Reward 847. LR=[1e-05]
# Worker 0 finished episode 4382. Reward 535. LR=[1e-05]
# Worker 3 finished episode 4383. Reward 589. LR=[1e-05]
# Worker 7 finished episode 4384. Reward 690. LR=[1e-05]
# Worker 2 finished episode 4385. Reward 584. LR=[1e-05]
# Worker 4 finished episode 4386. Reward 850. LR=[1e-05]
# Worker 1 finished episode 4387. Reward 567. LR=[1e-05]
# Worker 6 finished episode 4388. Reward 371. LR=[1e-05]
# Worker 5 finished episode 4389. Reward 619. LR=[1e-05]
# Worker 0 finished episode 4390. Reward 309. LR=[1e-05]
# Worker 3 finished episode 4391. Reward 871. LR=[1e-05]
# Worker 7 finished episode 4392. Reward 595. LR=[1e-05]
# Worker 2 finished episode 4393. Reward 437. LR=[1e-05]
# Worker 1 finished episode 4394. Reward 770. LR=[1e-05]
# Worker 4 finished episode 4395. Reward 316. LR=[1e-05]
# Worker 6 finished episode 4396. Reward 217. LR=[1e-05]
# Worker 5 finished episode 4397. Reward 440. LR=[1e-05]
# Worker 0 finished episode 4398. Reward 688. LR=[1e-05]
# Worker 3 finished episode 4399. Reward 754. LR=[1e-05]
# Worker 2 finished episode 4400. Reward 234. LR=[1e-05]
# Worker 7 finished episode 4401. Reward 836. LR=[1e-05]
# Worker 4 finished episode 4402. Reward 821. LR=[1e-05]
# Worker 1 finished episode 4403. Reward 474. LR=[1e-05]
# Worker 6 finished episode 4404. Reward 641. LR=[1e-05]
# Worker 5 finished episode 4405. Reward 781. LR=[1e-05]
# Worker 0 finished episode 4406. Reward 825. LR=[1e-05]
# Worker 3 finished episode 4407. Reward 463. LR=[1e-05]
# Worker 2 finished episode 4408. Reward 448. LR=[1e-05]
# Worker 7 finished episode 4409. Reward 806. LR=[1e-05]
# Worker 4 finished episode 4410. Reward 856. LR=[1e-05]
# Worker 6 finished episode 4411. Reward 651. LR=[1e-05]
# Worker 1 finished episode 4412. Reward 780. LR=[1e-05]
# Worker 5 finished episode 4413. Reward 714. LR=[1e-05]
# Worker 0 finished episode 4414. Reward 517. LR=[1e-05]
# Worker 2 finished episode 4415. Reward 335. LR=[1e-05]
# Worker 3 finished episode 4416. Reward 612. LR=[1e-05]
# Worker 7 finished episode 4417. Reward 338. LR=[1e-05]
# Worker 4 finished episode 4418. Reward 713. LR=[1e-05]
# Worker 6 finished episode 4419. Reward 778. LR=[1e-05]
# Worker 1 finished episode 4420. Reward 340. LR=[1e-05]
# Worker 5 finished episode 4421. Reward 900. LR=[1e-05]
# Worker 0 finished episode 4422. Reward 732. LR=[1e-05]
# Worker 2 finished episode 4423. Reward 852. LR=[1e-05]
# Worker 3 finished episode 4424. Reward 661. LR=[1e-05]
# Worker 7 finished episode 4425. Reward 827. LR=[1e-05]
# Worker 4 finished episode 4426. Reward 308. LR=[1e-05]
# Worker 6 finished episode 4427. Reward 631. LR=[1e-05]
# Worker 1 finished episode 4428. Reward 749. LR=[1e-05]
# Worker 5 finished episode 4429. Reward 534. LR=[1e-05]
# Worker 0 finished episode 4430. Reward 736. LR=[1e-05]
# Worker 3 finished episode 4431. Reward 755. LR=[1e-05]
# Worker 2 finished episode 4432. Reward 723. LR=[1e-05]
# Worker 7 finished episode 4433. Reward 818. LR=[1e-05]
# Worker 4 finished episode 4434. Reward 905. LR=[1e-05]
# Worker 6 finished episode 4435. Reward 539. LR=[1e-05]
# Worker 1 finished episode 4436. Reward 806. LR=[1e-05]
# Worker 5 finished episode 4437. Reward 759. LR=[1e-05]
# Worker 0 finished episode 4438. Reward 239. LR=[1e-05]
# Worker 3 finished episode 4439. Reward 638. LR=[1e-05]
# Worker 2 finished episode 4440. Reward 850. LR=[1e-05]
# Worker 7 finished episode 4441. Reward 426. LR=[1e-05]
# Worker 4 finished episode 4442. Reward 833. LR=[1e-05]
# Worker 6 finished episode 4443. Reward 280. LR=[1e-05]
# Worker 1 finished episode 4444. Reward 790. LR=[1e-05]
# Worker 0 finished episode 4445. Reward 669. LR=[1e-05]
# Worker 5 finished episode 4446. Reward 354. LR=[1e-05]
# Worker 3 finished episode 4447. Reward 288. LR=[1e-05]
# Worker 2 finished episode 4448. Reward 504. LR=[1e-05]
# Worker 7 finished episode 4449. Reward 887. LR=[1e-05]
# Worker 4 finished episode 4450. Reward 454. LR=[1e-05]
# Worker 6 finished episode 4451. Reward 609. LR=[1e-05]
# Worker 1 finished episode 4452. Reward 884. LR=[1e-05]
# Worker 5 finished episode 4453. Reward 622. LR=[1e-05]
# Worker 0 finished episode 4454. Reward 800. LR=[1e-05]
# Worker 2 finished episode 4455. Reward 726. LR=[1e-05]
# Worker 3 finished episode 4456. Reward 671. LR=[1e-05]
# Worker 7 finished episode 4457. Reward 478. LR=[1e-05]
# Worker 4 finished episode 4458. Reward 417. LR=[1e-05]
# Worker 6 finished episode 4459. Reward 882. LR=[1e-05]
# Worker 1 finished episode 4460. Reward 873. LR=[1e-05]
# Worker 5 finished episode 4461. Reward 355. LR=[1e-05]
# Worker 0 finished episode 4462. Reward 683. LR=[1e-05]
# Worker 2 finished episode 4463. Reward 457. LR=[1e-05]
# Worker 3 finished episode 4464. Reward 542. LR=[1e-05]
# Worker 7 finished episode 4465. Reward 601. LR=[1e-05]
# Worker 4 finished episode 4466. Reward 390. LR=[1e-05]
# Worker 1 finished episode 4467. Reward 814. LR=[1e-05]
# Worker 6 finished episode 4468. Reward 448. LR=[1e-05]
# Worker 5 finished episode 4469. Reward 545. LR=[1e-05]
# Worker 0 finished episode 4470. Reward 685. LR=[1e-05]
# Worker 2 finished episode 4471. Reward 866. LR=[1e-05]
# Worker 3 finished episode 4472. Reward 500. LR=[1e-05]
# Worker 7 finished episode 4473. Reward 830. LR=[1e-05]
# Worker 4 finished episode 4474. Reward 427. LR=[1e-05]
# Worker 1 finished episode 4475. Reward 534. LR=[1e-05]
# Worker 6 finished episode 4476. Reward 290. LR=[1e-05]
# Worker 5 finished episode 4477. Reward 617. LR=[1e-05]
# Worker 0 finished episode 4478. Reward 440. LR=[1e-05]
# Worker 2 finished episode 4479. Reward 393. LR=[1e-05]
# Worker 3 finished episode 4480. Reward 770. LR=[1e-05]
# Worker 7 finished episode 4481. Reward 684. LR=[1e-05]
# Worker 4 finished episode 4482. Reward 383. LR=[1e-05]
# Worker 1 finished episode 4483. Reward 521. LR=[1e-05]
# Worker 6 finished episode 4484. Reward 322. LR=[1e-05]
# Worker 5 finished episode 4485. Reward 542. LR=[1e-05]
# Worker 0 finished episode 4486. Reward 884. LR=[1e-05]
# Worker 2 finished episode 4487. Reward 879. LR=[1e-05]
# Worker 3 finished episode 4488. Reward 865. LR=[1e-05]
# Worker 7 finished episode 4489. Reward 753. LR=[1e-05]
# Worker 4 finished episode 4490. Reward 906. LR=[1e-05]
# Worker 6 finished episode 4491. Reward 714. LR=[1e-05]
# Worker 1 finished episode 4492. Reward 675. LR=[1e-05]
# Worker 5 finished episode 4493. Reward 630. LR=[1e-05]
# Worker 0 finished episode 4494. Reward 466. LR=[1e-05]
# Worker 2 finished episode 4495. Reward 765. LR=[1e-05]
# Worker 3 finished episode 4496. Reward 861. LR=[1e-05]
# Worker 7 finished episode 4497. Reward 386. LR=[1e-05]
# Worker 4 finished episode 4498. Reward 501. LR=[1e-05]
# Worker 6 finished episode 4499. Reward 516. LR=[1e-05]
# Worker 1 finished episode 4500. Reward 356. LR=[1e-05]
# Worker 5 finished episode 4501. Reward 281. LR=[1e-05]
# Worker 0 finished episode 4502. Reward 894. LR=[1e-05]
# Worker 2 finished episode 4503. Reward 852. LR=[1e-05]
# Worker 3 finished episode 4504. Reward 878. LR=[1e-05]
# Worker 7 finished episode 4505. Reward 412. LR=[1e-05]
# Worker 4 finished episode 4506. Reward 531. LR=[1e-05]
# Worker 6 finished episode 4507. Reward 538. LR=[1e-05]
# Worker 1 finished episode 4508. Reward 663. LR=[1e-05]
# Worker 5 finished episode 4509. Reward 394. LR=[1e-05]
# Worker 0 finished episode 4510. Reward 596. LR=[1e-05]
# Worker 2 finished episode 4511. Reward 850. LR=[1e-05]
# Worker 3 finished episode 4512. Reward 606. LR=[1e-05]
# Worker 7 finished episode 4513. Reward 851. LR=[1e-05]
# Worker 4 finished episode 4514. Reward 607. LR=[1e-05]
# Worker 1 finished episode 4515. Reward 440. LR=[1e-05]
# Worker 6 finished episode 4516. Reward 407. LR=[1e-05]
# Worker 5 finished episode 4517. Reward 639. LR=[1e-05]
# Worker 0 finished episode 4518. Reward 601. LR=[1e-05]
# Worker 2 finished episode 4519. Reward 818. LR=[1e-05]
# Worker 7 finished episode 4520. Reward 429. LR=[1e-05]
# Worker 3 finished episode 4521. Reward 752. LR=[1e-05]
# Worker 4 finished episode 4522. Reward 858. LR=[1e-05]
# Worker 6 finished episode 4523. Reward 805. LR=[1e-05]
# Worker 1 finished episode 4524. Reward 367. LR=[1e-05]
# Worker 5 finished episode 4525. Reward 511. LR=[1e-05]
# Worker 0 finished episode 4526. Reward 649. LR=[1e-05]
# Worker 2 finished episode 4527. Reward 428. LR=[1e-05]
# Worker 7 finished episode 4528. Reward 851. LR=[1e-05]
# Worker 3 finished episode 4529. Reward 560. LR=[1e-05]
# Worker 4 finished episode 4530. Reward 784. LR=[1e-05]
# Worker 6 finished episode 4531. Reward 528. LR=[1e-05]
# Worker 1 finished episode 4532. Reward 725. LR=[1e-05]
# Worker 0 finished episode 4533. Reward 802. LR=[1e-05]
# Worker 5 finished episode 4534. Reward 316. LR=[1e-05]
# Worker 7 finished episode 4535. Reward 856. LR=[1e-05]
# Worker 2 finished episode 4536. Reward 869. LR=[1e-05]
# Worker 3 finished episode 4537. Reward 702. LR=[1e-05]
# Worker 4 finished episode 4538. Reward 408. LR=[1e-05]
# Worker 6 finished episode 4539. Reward 424. LR=[1e-05]
# Worker 1 finished episode 4540. Reward 605. LR=[1e-05]
# Worker 5 finished episode 4541. Reward 127. LR=[1e-05]
# Worker 0 finished episode 4542. Reward 759. LR=[1e-05]
# Worker 3 finished episode 4543. Reward 904. LR=[1e-05]
# Worker 2 finished episode 4544. Reward 343. LR=[1e-05]
# Worker 7 finished episode 4545. Reward 554. LR=[1e-05]
# Worker 4 finished episode 4546. Reward 376. LR=[1e-05]
# Worker 6 finished episode 4547. Reward 651. LR=[1e-05]
# Worker 1 finished episode 4548. Reward 899. LR=[1e-05]
# Worker 0 finished episode 4549. Reward 909. LR=[1e-05]
# Worker 5 finished episode 4550. Reward 751. LR=[1e-05]
# Worker 3 finished episode 4551. Reward 529. LR=[1e-05]
# Worker 2 finished episode 4552. Reward 355. LR=[1e-05]
# Worker 7 finished episode 4553. Reward 454. LR=[1e-05]
# Worker 4 finished episode 4554. Reward 619. LR=[1e-05]
# Worker 6 finished episode 4555. Reward 714. LR=[1e-05]
# Worker 1 finished episode 4556. Reward 613. LR=[1e-05]
# Worker 5 finished episode 4557. Reward 601. LR=[1e-05]
# Worker 0 finished episode 4558. Reward 860. LR=[1e-05]
# Worker 2 finished episode 4559. Reward 386. LR=[1e-05]
# Worker 3 finished episode 4560. Reward 861. LR=[1e-05]
# Worker 7 finished episode 4561. Reward 625. LR=[1e-05]
# Worker 4 finished episode 4562. Reward 184. LR=[1e-05]
# Worker 6 finished episode 4563. Reward 518. LR=[1e-05]
# Worker 1 finished episode 4564. Reward 630. LR=[1e-05]
# Worker 0 finished episode 4565. Reward 374. LR=[1e-05]
# Worker 5 finished episode 4566. Reward 579. LR=[1e-05]
# Worker 2 finished episode 4567. Reward 509. LR=[1e-05]
# Worker 3 finished episode 4568. Reward 477. LR=[1e-05]
# Worker 4 finished episode 4569. Reward 706. LR=[1e-05]
# Worker 7 finished episode 4570. Reward 842. LR=[1e-05]
# Worker 6 finished episode 4571. Reward 526. LR=[1e-05]
# Worker 1 finished episode 4572. Reward 710. LR=[1e-05]
# Worker 0 finished episode 4573. Reward 495. LR=[1e-05]
# Worker 5 finished episode 4574. Reward 599. LR=[1e-05]
# Worker 2 finished episode 4575. Reward 738. LR=[1e-05]
# Worker 3 finished episode 4576. Reward 510. LR=[1e-05]
# Worker 4 finished episode 4577. Reward 526. LR=[1e-05]
# Worker 7 finished episode 4578. Reward 716. LR=[1e-05]
# Worker 6 finished episode 4579. Reward 604. LR=[1e-05]
# Worker 1 finished episode 4580. Reward 673. LR=[1e-05]
# Worker 5 finished episode 4581. Reward 492. LR=[1e-05]
# Worker 0 finished episode 4582. Reward 566. LR=[1e-05]
# Worker 2 finished episode 4583. Reward 222. LR=[1e-05]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[135], line 16
#       1 manager = Manager (
#       2     gamma = 0.99,
#       3     lr = 0.00001,
#    (...)
#      13     fstack_size = 4
#      14 )
# ---> 16 manager.train_model()
#
# Cell In[134], line 79, in Manager.train_model(self)
#      76 for worker in self.workers:
#      77     if worker.is_alive():
# ---> 79         ep_reward, returns, log_probs, values, entropies, steps = worker.get_n_step_data(self.steps_per_update, self.gamma)
#      80         if ep_reward is not None:
#      81             terminal = True
#
# Cell In[133], line 130, in Worker.get_n_step_data(self, trajectory_len, gamma)
#     128 self.episode_reward += reward
#     129 self.last_steps_rewards.append(reward)
# --> 130 last_val = value_t.detach().item()
#     131 self.framestack.append(state)
#     134 if terminal or (step % trajectory_len == 0): #Закончилась траектория или эпизод
#     135     # Считаем дисконтированные награды
#
# KeyboardInterrupt:
